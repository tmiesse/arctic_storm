# %% [markdown]
# # Inflection analysis for Annual & Monthly Return Period Analysis Pipeline
#
# ### Description:
# This Python workflow ingests multi‑year ADCIRC+SWAN hindcast outputs to:
#
# Compute Annual Maxima & Inflection Years:
#
# Load yearly water‑level datasets.
#
# Derive each node’s annual maximum water surface elevation.
#
# Detect a single annual change‑point (“inflection year”) per node using a binary segmentation algorithm.
#
# Map and tabulate the most common inflection years on a North‑Polar‑Stereo plot.
#
# Calculate Monthly Return Levels Around Inflection:
#
# Resample the full time series into monthly maxima.
#
# For each node, split its monthly series at the detected inflection year into pre‑ and post‑periods.
#
# Fit a Gumbel distribution to each segment and estimate T‑year return levels (e.g., 10, 50, 100, 500 years).
#
# Visualize Results:
#
# Annual: Polar scatter of top inflection years with a discrete colorbar.
#
# Monthly: A 6×6 grid of polar maps showing pre‑ vs. post‑inflection return levels by month, plus the percent change (ΔT), all annotated with month labels, panel IDs, and shared colorbars.

# %% [markdown]
# ### Initialize Libraries

# %%
import warnings;            import os
import pathlib as pl;       import string
import calendar;            import numpy as np
import pandas as pd;        import xarray as xr
import ruptures as rpt;     import matplotlib.pyplot as plt
import matplotlib as mpl;   import cartopy.crs as ccrs
import cartopy.feature as cfeature
from dask.distributed import Client, LocalCluster
from scipy.stats import pearsonr, genextreme, gumbel_r
from statsmodels.tsa.stattools import adfuller, kpss
from statsmodels.tools.sm_exceptions import HypothesisTestWarning
warnings.filterwarnings("ignore")

# %%
def compute_keep_idx(sample_path, min_depth, max_depth, bbox=None):
    """
    Return indices of nodes whose depth ∈ [min_depth, max_depth],
    optionally also within (min_x, max_x, min_y, max_y).
    """
    ds = xr.open_dataset(sample_path, engine="netcdf4", mask_and_scale=False)
    depth = ds.depth.values
    fv    = ds.depth.encoding.get("_FillValue", None)

    mask = np.ones_like(depth, dtype=bool)
    if fv is not None:
        mask &= (depth != fv)
    mask &= (depth >= min_depth) & (depth <= max_depth)

    if bbox is not None:
        min_x, max_x, min_y, max_y = bbox
        x, y = ds.x.values, ds.y.values
        mask &= (x >= min_x) & (x <= max_x) & (y >= min_y) & (y <= max_y)

    ds.close()
    return np.where(mask)[0]


def preprocess(ds):
    """Keep only the spin‑up‑free calendar year & shallow nodes."""
    ds = ds.assign_coords(time=pd.to_datetime(ds.time.values))
    year = ds.time.dt.year.values[600]
    mask = ds.time.dt.year == year
    return ds.isel(time=mask, node=keep_idx)


# ─── Change-point detection function ──────────────────────────────────────────
def detect_cp_annual(y, years_array, n_bkps=1):
    """
    Identify one change-point in a 1D annual series using ruptures.
    Returns the corresponding year or NaN if no valid break.
    """
    # need at least 5 valid points
    if np.sum(~np.isnan(y)) < 5:
        return np.nan

    algo = rpt.Binseg(model='rbf').fit(y.reshape(-1, 1))
    bkps = algo.predict(n_bkps=n_bkps)  # e.g., [idx]
    cp   = bkps[0]

    # ensure break is interior
    if 0 < cp < len(years_array):
        return years_array[cp]
    return np.nan

def test_stationarity(arr, alpha=0.05):
    """
    Returns (is_stationary, p_adf, p_kpss) for a 1D array.
    ADF stationary if p_adf < alpha; KPSS stationary if p_kpss > alpha.
    """
    # ADF
    with warnings.catch_warnings():
        warnings.simplefilter("ignore", HypothesisTestWarning)
        try:
            p_adf = adfuller(arr, autolag='AIC')[1]
        except Exception:
            p_adf = 0.0
    # KPSS
    with warnings.catch_warnings():
        warnings.simplefilter("ignore", HypothesisTestWarning)
        try:
            p_kpss = kpss(arr, regression='c', nlags='auto')[1]
        except Exception:
            p_kpss = 1.0

    p_adf  = min(max(p_adf, 0.0), 1.0)
    p_kpss = min(max(p_kpss, 0.0), 1.0)
    return (p_adf < alpha) and (p_kpss > alpha), p_adf, p_kpss


def make_labels(n):
    """Generate ‘a.’, ‘b.’ … ‘z.’, ‘aa.’, … for n panels."""
    labels = []
    alphabet = string.ascii_lowercase
    i = 0
    while len(labels) < n:
        s, x = '', i
        while True:
            s = alphabet[x % 26] + s
            x = x // 26 - 1
            if x < 0:
                break
        labels.append(s + '.')
        i += 1
    return labels

# %%
# ─── User‑set parameters ──────────────────────────────────────────────────────
lat1, lat2 = 56, 75
lon1, lon2 = -168.5, -140
root       =  '/groups/ORC-CLIMATE/fhrl_repo/Arctic_Database/converted_outputs'
YEARS      = range(1980, 2025)
MIN_DEPTH  = 0.5
MAX_DEPTH  = 5
bbox       = (lon1, lon2, lat1, lat2)

# compute shallow nodes index
sample_path = f"{root}/2023/fort.63.cf.nc"
keep_idx    = compute_keep_idx(sample_path, MIN_DEPTH, MAX_DEPTH, bbox)
print(f"Keeping {len(keep_idx)} nodes")
# Out:
# Keeping 182574 nodes

# %%
# ─── Spin up a Dask cluster ───────────────────────────────────────────────────
n_workers   = int(os.environ.get("SLURM_NTASKS", "45"))
mem_per_cpu = os.environ.get("SLURM_MEM_PER_CPU", "72GB")
cluster     = LocalCluster(
    n_workers=n_workers,
    threads_per_worker=1,
    processes=True,
    memory_limit=mem_per_cpu
)
client = Client(cluster)
print(client)
# Out:
# <Client: 'tcp://127.0.0.1:43665' processes=45 threads=45, memory=2.95 TiB>
# 2025-11-06 10:27:00,088 - distributed.scheduler - WARNING - Worker failed to heartbeat for 502s; attempting restart: <WorkerState 'tcp://127.0.0.1:32787', name: 26, status: running, memory: 0, processing: 0>
# 2025-11-06 10:27:04,127 - distributed.scheduler - WARNING - Worker failed to heartbeat for 454s; attempting restart: <WorkerState 'tcp://127.0.0.1:33055', name: 28, status: running, memory: 0, processing: 0>
# 2025-11-06 10:27:04,290 - distributed.scheduler - WARNING - Worker failed to heartbeat for 454s; attempting restart: <WorkerState 'tcp://127.0.0.1:33199', name: 37, status: running, memory: 0, processing: 0>
# 2025-11-06 10:27:06,381 - distributed.scheduler - WARNING - Worker failed to heartbeat for 420s; attempting restart: <WorkerState 'tcp://127.0.0.1:33383', name: 44, status: running, memory: 0, processing: 0>
# 2025-11-06 10:27:08,473 - distributed.scheduler - WARNING - Worker failed to heartbeat for 498s; attempting restart: <WorkerState 'tcp://127.0.0.1:33439', name: 7, status: running, memory: 0, processing: 0>
# 2025-11-06 10:27:08,473 - distributed.scheduler - WARNING - Worker failed to heartbeat for 508s; attempting restart: <WorkerState 'tcp://127.0.0.1:33857', name: 5, status: running, memory: 0, processing: 0>
# 2025-11-06 10:27:10,558 - distributed.scheduler - WARNING - Worker failed to heartbeat for 422s; attempting restart: <WorkerState 'tcp://127.0.0.1:33895', name: 33, status: running, memory: 0, processing: 0>
# 2025-11-06 10:27:12,629 - distributed.scheduler - WARNING - Worker failed to heartbeat for 506s; attempting restart: <WorkerState 'tcp://127.0.0.1:33955', name: 13, status: running, memory: 0, processing: 0>
# 2025-11-06 10:27:14,224 - distributed.scheduler - WARNING - Worker failed to heartbeat for 460s; attempting restart: <WorkerState 'tcp://127.0.0.1:34233', name: 8, status: running, memory: 0, processing: 0>
# 2025-11-06 10:27:16,871 - distributed.scheduler - WARNING - Worker failed to heartbeat for 429s; attempting restart: <WorkerState 'tcp://127.0.0.1:34415', name: 16, status: running, memory: 0, processing: 0>
# 2025-11-06 10:27:16,872 - distributed.scheduler - WARNING - Worker failed to heartbeat for 477s; attempting restart: <WorkerState 'tcp://127.0.0.1:34567', name: 25, status: running, memory: 0, processing: 0>
# 2025-11-06 10:27:18,969 - distributed.scheduler - WARNING - Worker failed to heartbeat for 454s; attempting restart: <WorkerState 'tcp://127.0.0.1:34603', name: 35, status: running, memory: 0, processing: 0>
# 2025-11-06 10:27:18,970 - distributed.scheduler - WARNING - Worker failed to heartbeat for 485s; attempting restart: <WorkerState 'tcp://127.0.0.1:35249', name: 17, status: running, memory: 0, processing: 0>
# 2025-11-06 10:27:21,058 - distributed.scheduler - WARNING - Worker failed to heartbeat for 495s; attempting restart: <WorkerState 'tcp://127.0.0.1:35807', name: 6, status: running, memory: 0, processing: 0>
# 2025-11-06 10:27:24,047 - distributed.scheduler - WARNING - Worker failed to heartbeat for 451s; attempting restart: <WorkerState 'tcp://127.0.0.1:36013', name: 36, status: running, memory: 0, processing: 0>
# 2025-11-06 10:27:25,242 - distributed.scheduler - WARNING - Worker failed to heartbeat for 426s; attempting restart: <WorkerState 'tcp://127.0.0.1:36709', name: 31, status: running, memory: 0, processing: 0>
# 2025-11-06 10:27:26,307 - distributed.scheduler - WARNING - Worker failed to heartbeat for 500s; attempting restart: <WorkerState 'tcp://127.0.0.1:36711', name: 20, status: running, memory: 0, processing: 0>
# 2025-11-06 10:27:29,487 - distributed.scheduler - WARNING - Worker failed to heartbeat for 468s; attempting restart: <WorkerState 'tcp://127.0.0.1:37085', name: 14, status: running, memory: 0, processing: 0>
# 2025-11-06 10:27:31,597 - distributed.scheduler - WARNING - Worker failed to heartbeat for 424s; attempting restart: <WorkerState 'tcp://127.0.0.1:37099', name: 19, status: running, memory: 0, processing: 0>
# 2025-11-06 10:27:35,813 - distributed.scheduler - WARNING - Worker failed to heartbeat for 456s; attempting restart: <WorkerState 'tcp://127.0.0.1:37373', name: 40, status: running, memory: 0, processing: 0>
# 2025-11-06 10:27:42,139 - distributed.scheduler - WARNING - Worker failed to heartbeat for 447s; attempting restart: <WorkerState 'tcp://127.0.0.1:37559', name: 41, status: running, memory: 0, processing: 0>
# 2025-11-06 10:27:44,268 - distributed.scheduler - WARNING - Worker failed to heartbeat for 458s; attempting restart: <WorkerState 'tcp://127.0.0.1:37821', name: 38, status: running, memory: 0, processing: 0>
# 2025-11-06 10:27:46,359 - distributed.scheduler - WARNING - Worker failed to heartbeat for 510s; attempting restart: <WorkerState 'tcp://127.0.0.1:38501', name: 0, status: running, memory: 0, processing: 0>
# 2025-11-06 10:27:50,477 - distributed.scheduler - WARNING - Worker failed to heartbeat for 504s; attempting restart: <WorkerState 'tcp://127.0.0.1:39597', name: 18, status: running, memory: 0, processing: 0>
# 2025-11-06 10:27:50,478 - distributed.scheduler - WARNING - Worker failed to heartbeat for 426s; attempting restart: <WorkerState 'tcp://127.0.0.1:39933', name: 15, status: running, memory: 0, processing: 0>
# 2025-11-06 10:27:52,532 - distributed.scheduler - WARNING - Worker failed to heartbeat for 429s; attempting restart: <WorkerState 'tcp://127.0.0.1:40385', name: 27, status: running, memory: 0, processing: 0>
# 2025-11-06 10:27:52,533 - distributed.scheduler - WARNING - Worker failed to heartbeat for 466s; attempting restart: <WorkerState 'tcp://127.0.0.1:40619', name: 22, status: running, memory: 0, processing: 0>
# 2025-11-06 10:27:52,533 - distributed.scheduler - WARNING - Worker failed to heartbeat for 437s; attempting restart: <WorkerState 'tcp://127.0.0.1:40965', name: 34, status: running, memory: 0, processing: 0>
# 2025-11-06 10:27:55,194 - distributed.scheduler - WARNING - Worker failed to heartbeat for 418s; attempting restart: <WorkerState 'tcp://127.0.0.1:41001', name: 29, status: running, memory: 0, processing: 0>
# 2025-11-06 10:27:55,195 - distributed.scheduler - WARNING - Worker failed to heartbeat for 431s; attempting restart: <WorkerState 'tcp://127.0.0.1:41019', name: 4, status: running, memory: 0, processing: 0>
# 2025-11-06 10:27:56,669 - distributed.scheduler - WARNING - Worker failed to heartbeat for 445s; attempting restart: <WorkerState 'tcp://127.0.0.1:41031', name: 42, status: running, memory: 0, processing: 0>
# 2025-11-06 10:27:58,731 - distributed.scheduler - WARNING - Worker failed to heartbeat for 500s; attempting restart: <WorkerState 'tcp://127.0.0.1:42345', name: 2, status: running, memory: 0, processing: 0>
# 2025-11-06 10:28:00,810 - distributed.scheduler - WARNING - Worker failed to heartbeat for 449s; attempting restart: <WorkerState 'tcp://127.0.0.1:42571', name: 10, status: running, memory: 0, processing: 0>
# 2025-11-06 10:28:05,008 - distributed.scheduler - WARNING - Worker failed to heartbeat for 441s; attempting restart: <WorkerState 'tcp://127.0.0.1:42761', name: 12, status: running, memory: 0, processing: 0>
# 2025-11-06 10:28:07,147 - distributed.scheduler - WARNING - Worker failed to heartbeat for 510s; attempting restart: <WorkerState 'tcp://127.0.0.1:42895', name: 43, status: running, memory: 0, processing: 0>
# 2025-11-06 10:28:08,738 - distributed.scheduler - WARNING - Worker failed to heartbeat for 495s; attempting restart: <WorkerState 'tcp://127.0.0.1:43273', name: 30, status: running, memory: 0, processing: 0>
# 2025-11-06 10:28:09,257 - distributed.scheduler - WARNING - Worker failed to heartbeat for 481s; attempting restart: <WorkerState 'tcp://127.0.0.1:43321', name: 32, status: running, memory: 0, processing: 0>
# 2025-11-06 10:28:13,399 - distributed.scheduler - WARNING - Worker failed to heartbeat for 481s; attempting restart: <WorkerState 'tcp://127.0.0.1:43325', name: 39, status: running, memory: 0, processing: 0>
# 2025-11-06 10:28:15,481 - distributed.scheduler - WARNING - Worker failed to heartbeat for 493s; attempting restart: <WorkerState 'tcp://127.0.0.1:44179', name: 9, status: running, memory: 0, processing: 0>
# 2025-11-06 10:28:17,566 - distributed.scheduler - WARNING - Worker failed to heartbeat for 439s; attempting restart: <WorkerState 'tcp://127.0.0.1:44431', name: 24, status: running, memory: 0, processing: 0>
# 2025-11-06 10:28:17,566 - distributed.scheduler - WARNING - Worker failed to heartbeat for 487s; attempting restart: <WorkerState 'tcp://127.0.0.1:44575', name: 3, status: running, memory: 0, processing: 0>
# 2025-11-06 10:28:21,738 - distributed.scheduler - WARNING - Worker failed to heartbeat for 470s; attempting restart: <WorkerState 'tcp://127.0.0.1:44689', name: 23, status: running, memory: 0, processing: 0>
# 2025-11-06 10:28:27,960 - distributed.scheduler - WARNING - Worker failed to heartbeat for 491s; attempting restart: <WorkerState 'tcp://127.0.0.1:44969', name: 11, status: running, memory: 0, processing: 0>
# 2025-11-06 10:28:30,007 - distributed.scheduler - WARNING - Worker failed to heartbeat for 483s; attempting restart: <WorkerState 'tcp://127.0.0.1:45911', name: 21, status: running, memory: 0, processing: 0>
# 2025-11-06 10:28:32,061 - distributed.scheduler - WARNING - Worker failed to heartbeat for 435s; attempting restart: <WorkerState 'tcp://127.0.0.1:46327', name: 1, status: running, memory: 0, processing: 0>
# 2025-11-06 11:26:35,915 - distributed.scheduler - ERROR - Workers ['tcp://127.0.0.1:40619', 'tcp://127.0.0.1:33199', 'tcp://127.0.0.1:43325', 'tcp://127.0.0.1:34233', 'tcp://127.0.0.1:42345', 'tcp://127.0.0.1:40385', 'tcp://127.0.0.1:39597', 'tcp://127.0.0.1:32787', 'tcp://127.0.0.1:33055', 'tcp://127.0.0.1:34567', 'tcp://127.0.0.1:37099', 'tcp://127.0.0.1:43273', 'tcp://127.0.0.1:33439', 'tcp://127.0.0.1:35807', 'tcp://127.0.0.1:34415', 'tcp://127.0.0.1:44431', 'tcp://127.0.0.1:33383', 'tcp://127.0.0.1:34603', 'tcp://127.0.0.1:40965', 'tcp://127.0.0.1:37373', 'tcp://127.0.0.1:39933', 'tcp://127.0.0.1:41001', 'tcp://127.0.0.1:37559', 'tcp://127.0.0.1:42895', 'tcp://127.0.0.1:46327', 'tcp://127.0.0.1:38501', 'tcp://127.0.0.1:41031', 'tcp://127.0.0.1:42571', 'tcp://127.0.0.1:44179', 'tcp://127.0.0.1:33955', 'tcp://127.0.0.1:44689', 'tcp://127.0.0.1:37821', 'tcp://127.0.0.1:43321', 'tcp://127.0.0.1:41019', 'tcp://127.0.0.1:36711', 'tcp://127.0.0.1:33857', 'tcp://127.0.0.1:45911', 'tcp://127.0.0.1:35249', 'tcp://127.0.0.1:37085', 'tcp://127.0.0.1:36013', 'tcp://127.0.0.1:44575', 'tcp://127.0.0.1:36709', 'tcp://127.0.0.1:42761', 'tcp://127.0.0.1:33895', 'tcp://127.0.0.1:44969'] did not shut down within 30s; force closing
# 2025-11-06 11:42:38,487 - distributed.scheduler - WARNING - Received heartbeat from unregistered worker 'tcp://127.0.0.1:42895'.
# 2025-11-06 11:42:48,851 - distributed.scheduler - WARNING - Received heartbeat from unregistered worker 'tcp://127.0.0.1:38501'.
# 2025-11-06 11:42:55,089 - distributed.scheduler - WARNING - Received heartbeat from unregistered worker 'tcp://127.0.0.1:33857'.
# 2025-11-06 11:42:59,106 - distributed.scheduler - WARNING - Received heartbeat from unregistered worker 'tcp://127.0.0.1:33955'.
# 2025-11-06 11:43:03,448 - distributed.scheduler - WARNING - Received heartbeat from unregistered worker 'tcp://127.0.0.1:39597'.
# 2025-11-06 11:43:07,590 - distributed.scheduler - WARNING - Received heartbeat from unregistered worker 'tcp://127.0.0.1:32787'.
# 2025-11-06 11:43:13,765 - distributed.scheduler - WARNING - Received heartbeat from unregistered worker 'tcp://127.0.0.1:36711'.
# 2025-11-06 11:43:17,384 - distributed.scheduler - WARNING - Received heartbeat from unregistered worker 'tcp://127.0.0.1:33439'.
# 2025-11-06 11:43:18,134 - distributed.scheduler - WARNING - Received heartbeat from unregistered worker 'tcp://127.0.0.1:42345'.
# 2025-11-06 11:43:20,012 - distributed.scheduler - WARNING - Received heartbeat from unregistered worker 'tcp://127.0.0.1:35807'.
# 2025-11-06 11:43:24,160 - distributed.scheduler - WARNING - Received heartbeat from unregistered worker 'tcp://127.0.0.1:43273'.
# 2025-11-06 11:43:26,237 - distributed.scheduler - WARNING - Received heartbeat from unregistered worker 'tcp://127.0.0.1:44179'.
# 2025-11-06 11:43:28,307 - distributed.scheduler - WARNING - Received heartbeat from unregistered worker 'tcp://127.0.0.1:44575'.
# 2025-11-06 11:43:32,459 - distributed.scheduler - WARNING - Received heartbeat from unregistered worker 'tcp://127.0.0.1:44969'.
# 2025-11-06 11:43:36,574 - distributed.scheduler - WARNING - Received heartbeat from unregistered worker 'tcp://127.0.0.1:35249'.
# 2025-11-06 11:43:40,757 - distributed.scheduler - WARNING - Received heartbeat from unregistered worker 'tcp://127.0.0.1:45911'.
# 2025-11-06 11:43:44,908 - distributed.scheduler - WARNING - Received heartbeat from unregistered worker 'tcp://127.0.0.1:43325'.
# 2025-11-06 11:43:49,073 - distributed.scheduler - WARNING - Received heartbeat from unregistered worker 'tcp://127.0.0.1:43321'.
# 2025-11-06 11:43:53,277 - distributed.scheduler - WARNING - Received heartbeat from unregistered worker 'tcp://127.0.0.1:44689'.
# 2025-11-06 11:43:57,623 - distributed.scheduler - WARNING - Received heartbeat from unregistered worker 'tcp://127.0.0.1:34567'.
# 2025-11-06 11:44:05,311 - distributed.scheduler - WARNING - Received heartbeat from unregistered worker 'tcp://127.0.0.1:40619'.
# 2025-11-06 11:44:07,798 - distributed.scheduler - WARNING - Received heartbeat from unregistered worker 'tcp://127.0.0.1:37085'.
# 2025-11-06 11:44:09,828 - distributed.scheduler - WARNING - Received heartbeat from unregistered worker 'tcp://127.0.0.1:37821'.
# 2025-11-06 11:44:15,957 - distributed.scheduler - WARNING - Received heartbeat from unregistered worker 'tcp://127.0.0.1:34233'.
# 2025-11-06 11:44:17,991 - distributed.scheduler - WARNING - Received heartbeat from unregistered worker 'tcp://127.0.0.1:37373'.
# 2025-11-06 11:44:17,992 - distributed.scheduler - WARNING - Received heartbeat from unregistered worker 'tcp://127.0.0.1:33199'.
# 2025-11-06 11:44:24,158 - distributed.scheduler - WARNING - Received heartbeat from unregistered worker 'tcp://127.0.0.1:34603'.
# 2025-11-06 11:44:32,346 - distributed.scheduler - WARNING - Received heartbeat from unregistered worker 'tcp://127.0.0.1:33055'.
# 2025-11-06 11:44:38,494 - distributed.scheduler - WARNING - Received heartbeat from unregistered worker 'tcp://127.0.0.1:36013'.
# 2025-11-06 11:44:40,502 - distributed.scheduler - WARNING - Received heartbeat from unregistered worker 'tcp://127.0.0.1:37559'.
# 2025-11-06 11:44:44,576 - distributed.scheduler - WARNING - Received heartbeat from unregistered worker 'tcp://127.0.0.1:42571'.
# 2025-11-06 11:44:48,721 - distributed.scheduler - WARNING - Received heartbeat from unregistered worker 'tcp://127.0.0.1:41031'.
# 2025-11-06 11:44:50,800 - distributed.scheduler - WARNING - Received heartbeat from unregistered worker 'tcp://127.0.0.1:42761'.
# 2025-11-06 11:44:59,064 - distributed.scheduler - WARNING - Received heartbeat from unregistered worker 'tcp://127.0.0.1:44431'.
# 2025-11-06 11:45:07,346 - distributed.scheduler - WARNING - Received heartbeat from unregistered worker 'tcp://127.0.0.1:40965'.
# 2025-11-06 11:45:11,482 - distributed.scheduler - WARNING - Received heartbeat from unregistered worker 'tcp://127.0.0.1:46327'.
# 2025-11-06 11:45:14,461 - distributed.scheduler - WARNING - Received heartbeat from unregistered worker 'tcp://127.0.0.1:41019'.
# 2025-11-06 11:45:21,710 - distributed.scheduler - WARNING - Received heartbeat from unregistered worker 'tcp://127.0.0.1:34415'.
# 2025-11-06 11:45:25,850 - distributed.scheduler - WARNING - Received heartbeat from unregistered worker 'tcp://127.0.0.1:40385'.
# 2025-11-06 11:45:32,039 - distributed.scheduler - WARNING - Received heartbeat from unregistered worker 'tcp://127.0.0.1:39933'.
# 2025-11-06 11:45:37,321 - distributed.scheduler - WARNING - Received heartbeat from unregistered worker 'tcp://127.0.0.1:36709'.
# 2025-11-06 11:45:38,228 - distributed.scheduler - WARNING - Received heartbeat from unregistered worker 'tcp://127.0.0.1:37099'.
# 2025-11-06 11:45:40,327 - distributed.scheduler - WARNING - Received heartbeat from unregistered worker 'tcp://127.0.0.1:33895'.
# 2025-11-06 11:45:43,194 - distributed.scheduler - WARNING - Received heartbeat from unregistered worker 'tcp://127.0.0.1:33383'.
# 2025-11-06 11:45:46,560 - distributed.scheduler - WARNING - Received heartbeat from unregistered worker 'tcp://127.0.0.1:41001'.
# 2025-11-06 11:49:19,206 - distributed.scheduler - ERROR - 45/45 nanny worker(s) did not shut down within 30s: {'tcp://127.0.0.1:40619', 'tcp://127.0.0.1:33199', 'tcp://127.0.0.1:43325', 'tcp://127.0.0.1:34233', 'tcp://127.0.0.1:42345', 'tcp://127.0.0.1:40385', 'tcp://127.0.0.1:39597', 'tcp://127.0.0.1:32787', 'tcp://127.0.0.1:33055', 'tcp://127.0.0.1:34567', 'tcp://127.0.0.1:37099', 'tcp://127.0.0.1:43273', 'tcp://127.0.0.1:33439', 'tcp://127.0.0.1:35807', 'tcp://127.0.0.1:34415', 'tcp://127.0.0.1:44431', 'tcp://127.0.0.1:33383', 'tcp://127.0.0.1:34603', 'tcp://127.0.0.1:40965', 'tcp://127.0.0.1:37373', 'tcp://127.0.0.1:39933', 'tcp://127.0.0.1:41001', 'tcp://127.0.0.1:37559', 'tcp://127.0.0.1:42895', 'tcp://127.0.0.1:46327', 'tcp://127.0.0.1:38501', 'tcp://127.0.0.1:41031', 'tcp://127.0.0.1:42571', 'tcp://127.0.0.1:44179', 'tcp://127.0.0.1:33955', 'tcp://127.0.0.1:44689', 'tcp://127.0.0.1:37821', 'tcp://127.0.0.1:43321', 'tcp://127.0.0.1:41019', 'tcp://127.0.0.1:36711', 'tcp://127.0.0.1:33857', 'tcp://127.0.0.1:45911', 'tcp://127.0.0.1:35249', 'tcp://127.0.0.1:37085', 'tcp://127.0.0.1:36013', 'tcp://127.0.0.1:44575', 'tcp://127.0.0.1:36709', 'tcp://127.0.0.1:42761', 'tcp://127.0.0.1:33895', 'tcp://127.0.0.1:44969'}
# Traceback (most recent call last):
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/utils.py", line 805, in wrapper
#     return await func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/scheduler.py", line 6606, in restart_workers
#     raise TimeoutError(
# TimeoutError: 45/45 nanny worker(s) did not shut down within 30s: {'tcp://127.0.0.1:40619', 'tcp://127.0.0.1:33199', 'tcp://127.0.0.1:43325', 'tcp://127.0.0.1:34233', 'tcp://127.0.0.1:42345', 'tcp://127.0.0.1:40385', 'tcp://127.0.0.1:39597', 'tcp://127.0.0.1:32787', 'tcp://127.0.0.1:33055', 'tcp://127.0.0.1:34567', 'tcp://127.0.0.1:37099', 'tcp://127.0.0.1:43273', 'tcp://127.0.0.1:33439', 'tcp://127.0.0.1:35807', 'tcp://127.0.0.1:34415', 'tcp://127.0.0.1:44431', 'tcp://127.0.0.1:33383', 'tcp://127.0.0.1:34603', 'tcp://127.0.0.1:40965', 'tcp://127.0.0.1:37373', 'tcp://127.0.0.1:39933', 'tcp://127.0.0.1:41001', 'tcp://127.0.0.1:37559', 'tcp://127.0.0.1:42895', 'tcp://127.0.0.1:46327', 'tcp://127.0.0.1:38501', 'tcp://127.0.0.1:41031', 'tcp://127.0.0.1:42571', 'tcp://127.0.0.1:44179', 'tcp://127.0.0.1:33955', 'tcp://127.0.0.1:44689', 'tcp://127.0.0.1:37821', 'tcp://127.0.0.1:43321', 'tcp://127.0.0.1:41019', 'tcp://127.0.0.1:36711', 'tcp://127.0.0.1:33857', 'tcp://127.0.0.1:45911', 'tcp://127.0.0.1:35249', 'tcp://127.0.0.1:37085', 'tcp://127.0.0.1:36013', 'tcp://127.0.0.1:44575', 'tcp://127.0.0.1:36709', 'tcp://127.0.0.1:42761', 'tcp://127.0.0.1:33895', 'tcp://127.0.0.1:44969'}
# 2025-11-06 11:49:19,207 - distributed.scheduler - ERROR - 45/45 nanny worker(s) did not shut down within 30s: {'tcp://127.0.0.1:40619', 'tcp://127.0.0.1:33199', 'tcp://127.0.0.1:43325', 'tcp://127.0.0.1:34233', 'tcp://127.0.0.1:42345', 'tcp://127.0.0.1:40385', 'tcp://127.0.0.1:39597', 'tcp://127.0.0.1:32787', 'tcp://127.0.0.1:33055', 'tcp://127.0.0.1:34567', 'tcp://127.0.0.1:37099', 'tcp://127.0.0.1:43273', 'tcp://127.0.0.1:33439', 'tcp://127.0.0.1:35807', 'tcp://127.0.0.1:34415', 'tcp://127.0.0.1:44431', 'tcp://127.0.0.1:33383', 'tcp://127.0.0.1:34603', 'tcp://127.0.0.1:40965', 'tcp://127.0.0.1:37373', 'tcp://127.0.0.1:39933', 'tcp://127.0.0.1:41001', 'tcp://127.0.0.1:37559', 'tcp://127.0.0.1:42895', 'tcp://127.0.0.1:46327', 'tcp://127.0.0.1:38501', 'tcp://127.0.0.1:41031', 'tcp://127.0.0.1:42571', 'tcp://127.0.0.1:44179', 'tcp://127.0.0.1:33955', 'tcp://127.0.0.1:44689', 'tcp://127.0.0.1:37821', 'tcp://127.0.0.1:43321', 'tcp://127.0.0.1:41019', 'tcp://127.0.0.1:36711', 'tcp://127.0.0.1:33857', 'tcp://127.0.0.1:45911', 'tcp://127.0.0.1:35249', 'tcp://127.0.0.1:37085', 'tcp://127.0.0.1:36013', 'tcp://127.0.0.1:44575', 'tcp://127.0.0.1:36709', 'tcp://127.0.0.1:42761', 'tcp://127.0.0.1:33895', 'tcp://127.0.0.1:44969'}
# Traceback (most recent call last):
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/utils.py", line 805, in wrapper
#     return await func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/scheduler.py", line 8647, in check_worker_ttl
#     await self.restart_workers(
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/utils.py", line 805, in wrapper
#     return await func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/scheduler.py", line 6606, in restart_workers
#     raise TimeoutError(
# TimeoutError: 45/45 nanny worker(s) did not shut down within 30s: {'tcp://127.0.0.1:40619', 'tcp://127.0.0.1:33199', 'tcp://127.0.0.1:43325', 'tcp://127.0.0.1:34233', 'tcp://127.0.0.1:42345', 'tcp://127.0.0.1:40385', 'tcp://127.0.0.1:39597', 'tcp://127.0.0.1:32787', 'tcp://127.0.0.1:33055', 'tcp://127.0.0.1:34567', 'tcp://127.0.0.1:37099', 'tcp://127.0.0.1:43273', 'tcp://127.0.0.1:33439', 'tcp://127.0.0.1:35807', 'tcp://127.0.0.1:34415', 'tcp://127.0.0.1:44431', 'tcp://127.0.0.1:33383', 'tcp://127.0.0.1:34603', 'tcp://127.0.0.1:40965', 'tcp://127.0.0.1:37373', 'tcp://127.0.0.1:39933', 'tcp://127.0.0.1:41001', 'tcp://127.0.0.1:37559', 'tcp://127.0.0.1:42895', 'tcp://127.0.0.1:46327', 'tcp://127.0.0.1:38501', 'tcp://127.0.0.1:41031', 'tcp://127.0.0.1:42571', 'tcp://127.0.0.1:44179', 'tcp://127.0.0.1:33955', 'tcp://127.0.0.1:44689', 'tcp://127.0.0.1:37821', 'tcp://127.0.0.1:43321', 'tcp://127.0.0.1:41019', 'tcp://127.0.0.1:36711', 'tcp://127.0.0.1:33857', 'tcp://127.0.0.1:45911', 'tcp://127.0.0.1:35249', 'tcp://127.0.0.1:37085', 'tcp://127.0.0.1:36013', 'tcp://127.0.0.1:44575', 'tcp://127.0.0.1:36709', 'tcp://127.0.0.1:42761', 'tcp://127.0.0.1:33895', 'tcp://127.0.0.1:44969'}
# 2025-11-06 11:49:19,208 - tornado.application - ERROR - Exception in callback <bound method Scheduler.check_worker_ttl of <Scheduler 'tcp://127.0.0.1:43665', workers: 0, cores: 0, tasks: 0>>
# Traceback (most recent call last):
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/tornado/ioloop.py", line 939, in _run
#     await val
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/utils.py", line 805, in wrapper
#     return await func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/scheduler.py", line 8647, in check_worker_ttl
#     await self.restart_workers(
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/utils.py", line 805, in wrapper
#     return await func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/scheduler.py", line 6606, in restart_workers
#     raise TimeoutError(
# TimeoutError: 45/45 nanny worker(s) did not shut down within 30s: {'tcp://127.0.0.1:40619', 'tcp://127.0.0.1:33199', 'tcp://127.0.0.1:43325', 'tcp://127.0.0.1:34233', 'tcp://127.0.0.1:42345', 'tcp://127.0.0.1:40385', 'tcp://127.0.0.1:39597', 'tcp://127.0.0.1:32787', 'tcp://127.0.0.1:33055', 'tcp://127.0.0.1:34567', 'tcp://127.0.0.1:37099', 'tcp://127.0.0.1:43273', 'tcp://127.0.0.1:33439', 'tcp://127.0.0.1:35807', 'tcp://127.0.0.1:34415', 'tcp://127.0.0.1:44431', 'tcp://127.0.0.1:33383', 'tcp://127.0.0.1:34603', 'tcp://127.0.0.1:40965', 'tcp://127.0.0.1:37373', 'tcp://127.0.0.1:39933', 'tcp://127.0.0.1:41001', 'tcp://127.0.0.1:37559', 'tcp://127.0.0.1:42895', 'tcp://127.0.0.1:46327', 'tcp://127.0.0.1:38501', 'tcp://127.0.0.1:41031', 'tcp://127.0.0.1:42571', 'tcp://127.0.0.1:44179', 'tcp://127.0.0.1:33955', 'tcp://127.0.0.1:44689', 'tcp://127.0.0.1:37821', 'tcp://127.0.0.1:43321', 'tcp://127.0.0.1:41019', 'tcp://127.0.0.1:36711', 'tcp://127.0.0.1:33857', 'tcp://127.0.0.1:45911', 'tcp://127.0.0.1:35249', 'tcp://127.0.0.1:37085', 'tcp://127.0.0.1:36013', 'tcp://127.0.0.1:44575', 'tcp://127.0.0.1:36709', 'tcp://127.0.0.1:42761', 'tcp://127.0.0.1:33895', 'tcp://127.0.0.1:44969'}

# %%
client.close(),cluster.close()
# Out:
# (None, None)

# %%
# ─── Load & concatenate annual zeta ────────────────────────────────────────────
paths = [str(pl.Path(root)/str(y)/"fort.63.cf.nc") for y in YEARS]
ds_all = xr.open_mfdataset(
    paths,
    engine="h5netcdf",
    mask_and_scale=True,
    decode_cf=True,
    preprocess=preprocess,
    combine="nested",
    concat_dim="time",
    chunks={'time': 24},
    coords="minimal"
)
z       = ds_all.zeta.values
x_all   = ds_all.x.values
y_all   = ds_all.y.values
# Out:
# 2025-11-05 13:43:49,407 - distributed.worker - ERROR - failed during get data with tcp://127.0.0.1:41617 -> tcp://127.0.0.1:34529
# Traceback (most recent call last):
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/tornado/iostream.py", line 861, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/tornado/iostream.py", line 1116, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# TimeoutError: [Errno 110] Connection timed out
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/worker.py", line 1797, in get_data
#     response = await comm.read(deserializers=serializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/comm/tcp.py", line 237, in read
#     convert_stream_closed_error(self, e)
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/comm/tcp.py", line 143, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed)  local=tcp://127.0.0.1:41617 remote=tcp://127.0.0.1:46880>: TimeoutError: [Errno 110] Connection timed out
# 2025-11-05 13:43:50,431 - distributed.worker - ERROR - failed during get data with tcp://127.0.0.1:38135 -> tcp://127.0.0.1:34463
# Traceback (most recent call last):
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/tornado/iostream.py", line 861, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/tornado/iostream.py", line 1116, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# TimeoutError: [Errno 110] Connection timed out
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/worker.py", line 1797, in get_data
#     response = await comm.read(deserializers=serializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/comm/tcp.py", line 237, in read
#     convert_stream_closed_error(self, e)
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/comm/tcp.py", line 143, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed)  local=tcp://127.0.0.1:38135 remote=tcp://127.0.0.1:43258>: TimeoutError: [Errno 110] Connection timed out
# 2025-11-05 13:45:17,864 - distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:38135
# Traceback (most recent call last):
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/tornado/iostream.py", line 861, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/tornado/iostream.py", line 1116, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [Errno 104] Connection reset by peer
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/worker.py", line 2075, in gather_dep
#     response = await get_data_from_worker(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/worker.py", line 2881, in get_data_from_worker
#     response = await send_recv(
#                ^^^^^^^^^^^^^^^^
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/core.py", line 1018, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/comm/tcp.py", line 237, in read
#     convert_stream_closed_error(self, e)
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/comm/tcp.py", line 143, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) Ephemeral Worker->Worker for gather local=tcp://127.0.0.1:43258 remote=tcp://127.0.0.1:38135>: ConnectionResetError: [Errno 104] Connection reset by peer
# 2025-11-05 13:45:17,896 - distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:41617
# Traceback (most recent call last):
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/tornado/iostream.py", line 861, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/tornado/iostream.py", line 1116, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [Errno 104] Connection reset by peer
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/worker.py", line 2075, in gather_dep
#     response = await get_data_from_worker(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/worker.py", line 2881, in get_data_from_worker
#     response = await send_recv(
#                ^^^^^^^^^^^^^^^^
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/core.py", line 1018, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/comm/tcp.py", line 237, in read
#     convert_stream_closed_error(self, e)
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/comm/tcp.py", line 143, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) Ephemeral Worker->Worker for gather local=tcp://127.0.0.1:46880 remote=tcp://127.0.0.1:41617>: ConnectionResetError: [Errno 104] Connection reset by peer
# 2025-11-05 13:57:15,807 - distributed.worker - ERROR - failed during get data with tcp://127.0.0.1:35765 -> tcp://127.0.0.1:45037
# Traceback (most recent call last):
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/tornado/iostream.py", line 861, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/tornado/iostream.py", line 1116, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# TimeoutError: [Errno 110] Connection timed out
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/worker.py", line 1797, in get_data
#     response = await comm.read(deserializers=serializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/comm/tcp.py", line 237, in read
#     convert_stream_closed_error(self, e)
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/comm/tcp.py", line 143, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed)  local=tcp://127.0.0.1:35765 remote=tcp://127.0.0.1:38656>: TimeoutError: [Errno 110] Connection timed out
# 2025-11-05 13:59:59,389 - distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:35765
# Traceback (most recent call last):
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/tornado/iostream.py", line 861, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/tornado/iostream.py", line 1116, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [Errno 104] Connection reset by peer
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/worker.py", line 2075, in gather_dep
#     response = await get_data_from_worker(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/worker.py", line 2881, in get_data_from_worker
#     response = await send_recv(
#                ^^^^^^^^^^^^^^^^
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/core.py", line 1018, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/comm/tcp.py", line 237, in read
#     convert_stream_closed_error(self, e)
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/comm/tcp.py", line 143, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) Ephemeral Worker->Worker for gather local=tcp://127.0.0.1:38656 remote=tcp://127.0.0.1:35765>: ConnectionResetError: [Errno 104] Connection reset by peer
# 2025-11-05 14:03:57,727 - distributed.worker - ERROR - failed during get data with tcp://127.0.0.1:40885 -> tcp://127.0.0.1:41227
# Traceback (most recent call last):
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/tornado/iostream.py", line 861, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/tornado/iostream.py", line 1116, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# TimeoutError: [Errno 110] Connection timed out
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/worker.py", line 1797, in get_data
#     response = await comm.read(deserializers=serializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/comm/tcp.py", line 237, in read
#     convert_stream_closed_error(self, e)
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/comm/tcp.py", line 143, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed)  local=tcp://127.0.0.1:40885 remote=tcp://127.0.0.1:55776>: TimeoutError: [Errno 110] Connection timed out
# 2025-11-05 14:08:07,366 - distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:40885
# Traceback (most recent call last):
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/tornado/iostream.py", line 861, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/tornado/iostream.py", line 1116, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [Errno 104] Connection reset by peer
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/worker.py", line 2075, in gather_dep
#     response = await get_data_from_worker(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/worker.py", line 2881, in get_data_from_worker
#     response = await send_recv(
#                ^^^^^^^^^^^^^^^^
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/core.py", line 1018, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/comm/tcp.py", line 237, in read
#     convert_stream_closed_error(self, e)
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/comm/tcp.py", line 143, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) Ephemeral Worker->Worker for gather local=tcp://127.0.0.1:55776 remote=tcp://127.0.0.1:40885>: ConnectionResetError: [Errno 104] Connection reset by peer
# 2025-11-05 14:10:20,463 - distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:44733
# Traceback (most recent call last):
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/tornado/iostream.py", line 861, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/tornado/iostream.py", line 1116, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [Errno 104] Connection reset by peer
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/worker.py", line 2075, in gather_dep
#     response = await get_data_from_worker(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/worker.py", line 2881, in get_data_from_worker
#     response = await send_recv(
#                ^^^^^^^^^^^^^^^^
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/core.py", line 1018, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/comm/tcp.py", line 237, in read
#     convert_stream_closed_error(self, e)
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/comm/tcp.py", line 143, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) Ephemeral Worker->Worker for gather local=tcp://127.0.0.1:60156 remote=tcp://127.0.0.1:44733>: ConnectionResetError: [Errno 104] Connection reset by peer
# 2025-11-05 14:10:45,246 - distributed.worker - ERROR - failed during get data with tcp://127.0.0.1:44733 -> tcp://127.0.0.1:45037
# Traceback (most recent call last):
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/tornado/iostream.py", line 861, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/tornado/iostream.py", line 1116, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# TimeoutError: [Errno 110] Connection timed out
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/worker.py", line 1797, in get_data
#     response = await comm.read(deserializers=serializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/comm/tcp.py", line 237, in read
#     convert_stream_closed_error(self, e)
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/comm/tcp.py", line 143, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed)  local=tcp://127.0.0.1:44733 remote=tcp://127.0.0.1:60156>: TimeoutError: [Errno 110] Connection timed out
# 2025-11-05 14:21:15,039 - distributed.worker - ERROR - failed during get data with tcp://127.0.0.1:43909 -> tcp://127.0.0.1:36007
# Traceback (most recent call last):
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/tornado/iostream.py", line 861, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/tornado/iostream.py", line 1116, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# TimeoutError: [Errno 110] Connection timed out
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/worker.py", line 1797, in get_data
#     response = await comm.read(deserializers=serializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/comm/tcp.py", line 237, in read
#     convert_stream_closed_error(self, e)
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/comm/tcp.py", line 143, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed)  local=tcp://127.0.0.1:43909 remote=tcp://127.0.0.1:50578>: TimeoutError: [Errno 110] Connection timed out
# 2025-11-05 14:22:01,477 - distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:43909
# Traceback (most recent call last):
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/tornado/iostream.py", line 861, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/tornado/iostream.py", line 1116, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [Errno 104] Connection reset by peer
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/worker.py", line 2075, in gather_dep
#     response = await get_data_from_worker(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/worker.py", line 2881, in get_data_from_worker
#     response = await send_recv(
#                ^^^^^^^^^^^^^^^^
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/core.py", line 1018, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/comm/tcp.py", line 237, in read
#     convert_stream_closed_error(self, e)
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/comm/tcp.py", line 143, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) Ephemeral Worker->Worker for gather local=tcp://127.0.0.1:50578 remote=tcp://127.0.0.1:43909>: ConnectionResetError: [Errno 104] Connection reset by peer
# 2025-11-05 14:26:05,856 - distributed.worker - ERROR - failed during get data with tcp://127.0.0.1:41617 -> tcp://127.0.0.1:41265
# Traceback (most recent call last):
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/tornado/iostream.py", line 861, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/tornado/iostream.py", line 1116, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# TimeoutError: [Errno 110] Connection timed out
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/worker.py", line 1797, in get_data
#     response = await comm.read(deserializers=serializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/comm/tcp.py", line 237, in read
#     convert_stream_closed_error(self, e)
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/comm/tcp.py", line 143, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed)  local=tcp://127.0.0.1:41617 remote=tcp://127.0.0.1:40710>: TimeoutError: [Errno 110] Connection timed out
# 2025-11-05 14:27:31,573 - distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:41617
# Traceback (most recent call last):
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/tornado/iostream.py", line 861, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/tornado/iostream.py", line 1116, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [Errno 104] Connection reset by peer
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/worker.py", line 2075, in gather_dep
#     response = await get_data_from_worker(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/worker.py", line 2881, in get_data_from_worker
#     response = await send_recv(
#                ^^^^^^^^^^^^^^^^
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/core.py", line 1018, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/comm/tcp.py", line 237, in read
#     convert_stream_closed_error(self, e)
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/comm/tcp.py", line 143, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) Ephemeral Worker->Worker for gather local=tcp://127.0.0.1:40710 remote=tcp://127.0.0.1:41617>: ConnectionResetError: [Errno 104] Connection reset by peer
# 2025-11-05 14:40:00,415 - distributed.worker - ERROR - failed during get data with tcp://127.0.0.1:43005 -> tcp://127.0.0.1:37407
# Traceback (most recent call last):
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/tornado/iostream.py", line 861, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/tornado/iostream.py", line 1116, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# TimeoutError: [Errno 110] Connection timed out
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/worker.py", line 1797, in get_data
#     response = await comm.read(deserializers=serializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/comm/tcp.py", line 237, in read
#     convert_stream_closed_error(self, e)
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/comm/tcp.py", line 143, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed)  local=tcp://127.0.0.1:43005 remote=tcp://127.0.0.1:50848>: TimeoutError: [Errno 110] Connection timed out
# 2025-11-05 14:42:05,592 - distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:43005
# Traceback (most recent call last):
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/tornado/iostream.py", line 861, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/tornado/iostream.py", line 1116, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [Errno 104] Connection reset by peer
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/worker.py", line 2075, in gather_dep
#     response = await get_data_from_worker(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/worker.py", line 2881, in get_data_from_worker
#     response = await send_recv(
#                ^^^^^^^^^^^^^^^^
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/core.py", line 1018, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/comm/tcp.py", line 237, in read
#     convert_stream_closed_error(self, e)
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/comm/tcp.py", line 143, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) Ephemeral Worker->Worker for gather local=tcp://127.0.0.1:50848 remote=tcp://127.0.0.1:43005>: ConnectionResetError: [Errno 104] Connection reset by peer
# 2025-11-05 14:46:19,807 - distributed.worker - ERROR - failed during get data with tcp://127.0.0.1:34083 -> tcp://127.0.0.1:35765
# Traceback (most recent call last):
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/tornado/iostream.py", line 861, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/tornado/iostream.py", line 1116, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# TimeoutError: [Errno 110] Connection timed out
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/worker.py", line 1797, in get_data
#     response = await comm.read(deserializers=serializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/comm/tcp.py", line 237, in read
#     convert_stream_closed_error(self, e)
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/comm/tcp.py", line 143, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed)  local=tcp://127.0.0.1:34083 remote=tcp://127.0.0.1:42904>: TimeoutError: [Errno 110] Connection timed out
# 2025-11-05 14:48:13,041 - distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:34083
# Traceback (most recent call last):
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/tornado/iostream.py", line 861, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/tornado/iostream.py", line 1116, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [Errno 104] Connection reset by peer
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/worker.py", line 2075, in gather_dep
#     response = await get_data_from_worker(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/worker.py", line 2881, in get_data_from_worker
#     response = await send_recv(
#                ^^^^^^^^^^^^^^^^
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/core.py", line 1018, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/comm/tcp.py", line 237, in read
#     convert_stream_closed_error(self, e)
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/comm/tcp.py", line 143, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) Ephemeral Worker->Worker for gather local=tcp://127.0.0.1:42904 remote=tcp://127.0.0.1:34083>: ConnectionResetError: [Errno 104] Connection reset by peer
# 2025-11-05 14:55:52,735 - distributed.worker - ERROR - failed during get data with tcp://127.0.0.1:40885 -> tcp://127.0.0.1:39301
# Traceback (most recent call last):
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/tornado/iostream.py", line 861, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/tornado/iostream.py", line 1116, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# TimeoutError: [Errno 110] Connection timed out
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/worker.py", line 1797, in get_data
#     response = await comm.read(deserializers=serializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/comm/tcp.py", line 237, in read
#     convert_stream_closed_error(self, e)
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/comm/tcp.py", line 143, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed)  local=tcp://127.0.0.1:40885 remote=tcp://127.0.0.1:37058>: TimeoutError: [Errno 110] Connection timed out
# 2025-11-05 14:57:10,221 - distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:40885
# Traceback (most recent call last):
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/tornado/iostream.py", line 861, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/tornado/iostream.py", line 1116, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [Errno 104] Connection reset by peer
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/worker.py", line 2075, in gather_dep
#     response = await get_data_from_worker(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/worker.py", line 2881, in get_data_from_worker
#     response = await send_recv(
#                ^^^^^^^^^^^^^^^^
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/core.py", line 1018, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/comm/tcp.py", line 237, in read
#     convert_stream_closed_error(self, e)
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/comm/tcp.py", line 143, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) Ephemeral Worker->Worker for gather local=tcp://127.0.0.1:37058 remote=tcp://127.0.0.1:40885>: ConnectionResetError: [Errno 104] Connection reset by peer
# 2025-11-05 14:59:26,239 - distributed.worker - ERROR - failed during get data with tcp://127.0.0.1:38135 -> tcp://127.0.0.1:43005
# Traceback (most recent call last):
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/tornado/iostream.py", line 861, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/tornado/iostream.py", line 1116, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# TimeoutError: [Errno 110] Connection timed out
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/worker.py", line 1797, in get_data
#     response = await comm.read(deserializers=serializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/comm/tcp.py", line 237, in read
#     convert_stream_closed_error(self, e)
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/comm/tcp.py", line 143, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed)  local=tcp://127.0.0.1:38135 remote=tcp://127.0.0.1:54264>: TimeoutError: [Errno 110] Connection timed out
# 2025-11-05 14:59:38,527 - distributed.worker - ERROR - failed during get data with tcp://127.0.0.1:41617 -> tcp://127.0.0.1:42515
# Traceback (most recent call last):
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/tornado/iostream.py", line 861, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/tornado/iostream.py", line 1116, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# TimeoutError: [Errno 110] Connection timed out
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/worker.py", line 1797, in get_data
#     response = await comm.read(deserializers=serializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/comm/tcp.py", line 237, in read
#     convert_stream_closed_error(self, e)
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/comm/tcp.py", line 143, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed)  local=tcp://127.0.0.1:41617 remote=tcp://127.0.0.1:52584>: TimeoutError: [Errno 110] Connection timed out
# 2025-11-05 14:59:39,551 - distributed.worker - ERROR - failed during get data with tcp://127.0.0.1:40885 -> tcp://127.0.0.1:44347
# Traceback (most recent call last):
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/tornado/iostream.py", line 861, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/tornado/iostream.py", line 1116, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# TimeoutError: [Errno 110] Connection timed out
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/worker.py", line 1797, in get_data
#     response = await comm.read(deserializers=serializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/comm/tcp.py", line 237, in read
#     convert_stream_closed_error(self, e)
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/comm/tcp.py", line 143, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed)  local=tcp://127.0.0.1:40885 remote=tcp://127.0.0.1:41358>: TimeoutError: [Errno 110] Connection timed out
# 2025-11-05 14:59:40,576 - distributed.worker - ERROR - failed during get data with tcp://127.0.0.1:40885 -> tcp://127.0.0.1:44733
# Traceback (most recent call last):
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/tornado/iostream.py", line 861, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/tornado/iostream.py", line 1116, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# TimeoutError: [Errno 110] Connection timed out
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/worker.py", line 1797, in get_data
#     response = await comm.read(deserializers=serializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/comm/tcp.py", line 237, in read
#     convert_stream_closed_error(self, e)
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/comm/tcp.py", line 143, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed)  local=tcp://127.0.0.1:40885 remote=tcp://127.0.0.1:41212>: TimeoutError: [Errno 110] Connection timed out
# 2025-11-05 15:02:32,454 - distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:38135
# Traceback (most recent call last):
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/tornado/iostream.py", line 861, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/tornado/iostream.py", line 1116, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [Errno 104] Connection reset by peer
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/worker.py", line 2075, in gather_dep
#     response = await get_data_from_worker(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/worker.py", line 2881, in get_data_from_worker
#     response = await send_recv(
#                ^^^^^^^^^^^^^^^^
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/core.py", line 1018, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/comm/tcp.py", line 237, in read
#     convert_stream_closed_error(self, e)
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/comm/tcp.py", line 143, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) Ephemeral Worker->Worker for gather local=tcp://127.0.0.1:54264 remote=tcp://127.0.0.1:38135>: ConnectionResetError: [Errno 104] Connection reset by peer
# 2025-11-05 15:02:32,236 - distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:40885
# Traceback (most recent call last):
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/tornado/iostream.py", line 861, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/tornado/iostream.py", line 1116, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [Errno 104] Connection reset by peer
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/worker.py", line 2075, in gather_dep
#     response = await get_data_from_worker(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/worker.py", line 2881, in get_data_from_worker
#     response = await send_recv(
#                ^^^^^^^^^^^^^^^^
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/core.py", line 1018, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/comm/tcp.py", line 237, in read
#     convert_stream_closed_error(self, e)
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/comm/tcp.py", line 143, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) Ephemeral Worker->Worker for gather local=tcp://127.0.0.1:41358 remote=tcp://127.0.0.1:40885>: ConnectionResetError: [Errno 104] Connection reset by peer
# 2025-11-05 15:02:32,455 - distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:41617
# Traceback (most recent call last):
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/tornado/iostream.py", line 861, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/tornado/iostream.py", line 1116, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [Errno 104] Connection reset by peer
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/worker.py", line 2075, in gather_dep
#     response = await get_data_from_worker(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/worker.py", line 2881, in get_data_from_worker
#     response = await send_recv(
#                ^^^^^^^^^^^^^^^^
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/core.py", line 1018, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/comm/tcp.py", line 237, in read
#     convert_stream_closed_error(self, e)
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/comm/tcp.py", line 143, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) Ephemeral Worker->Worker for gather local=tcp://127.0.0.1:52584 remote=tcp://127.0.0.1:41617>: ConnectionResetError: [Errno 104] Connection reset by peer
# 2025-11-05 15:02:32,483 - distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:40885
# Traceback (most recent call last):
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/tornado/iostream.py", line 861, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/tornado/iostream.py", line 1116, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [Errno 104] Connection reset by peer
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
# ...
# Traceback (most recent call last):
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/tornado/iostream.py", line 861, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/tornado/iostream.py", line 1116, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# TimeoutError: [Errno 110] Connection timed out
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/worker.py", line 1797, in get_data
#     response = await comm.read(deserializers=serializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/comm/tcp.py", line 237, in read
#     convert_stream_closed_error(self, e)
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/comm/tcp.py", line 143, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed)  local=tcp://127.0.0.1:40595 remote=tcp://127.0.0.1:60218>: TimeoutError: [Errno 110] Connection timed out
# 2025-11-05 15:28:43,424 - distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:40595
# Traceback (most recent call last):
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/tornado/iostream.py", line 861, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/tornado/iostream.py", line 1116, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [Errno 104] Connection reset by peer
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/worker.py", line 2075, in gather_dep
#     response = await get_data_from_worker(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/worker.py", line 2881, in get_data_from_worker
#     response = await send_recv(
#                ^^^^^^^^^^^^^^^^
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/core.py", line 1018, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/comm/tcp.py", line 237, in read
#     convert_stream_closed_error(self, e)
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/comm/tcp.py", line 143, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) Ephemeral Worker->Worker for gather local=tcp://127.0.0.1:60218 remote=tcp://127.0.0.1:40595>: ConnectionResetError: [Errno 104] Connection reset by peer
# 2025-11-05 15:28:43,423 - distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:43005
# Traceback (most recent call last):
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/tornado/iostream.py", line 861, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/tornado/iostream.py", line 1116, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [Errno 104] Connection reset by peer
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/worker.py", line 2075, in gather_dep
#     response = await get_data_from_worker(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/worker.py", line 2881, in get_data_from_worker
#     response = await send_recv(
#                ^^^^^^^^^^^^^^^^
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/core.py", line 1018, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/comm/tcp.py", line 237, in read
#     convert_stream_closed_error(self, e)
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/comm/tcp.py", line 143, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) Ephemeral Worker->Worker for gather local=tcp://127.0.0.1:42558 remote=tcp://127.0.0.1:43005>: ConnectionResetError: [Errno 104] Connection reset by peer
# 2025-11-05 15:32:26,143 - distributed.worker - ERROR - failed during get data with tcp://127.0.0.1:36007 -> tcp://127.0.0.1:39301
# Traceback (most recent call last):
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/tornado/iostream.py", line 861, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/tornado/iostream.py", line 1116, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# TimeoutError: [Errno 110] Connection timed out
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/worker.py", line 1797, in get_data
#     response = await comm.read(deserializers=serializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/comm/tcp.py", line 237, in read
#     convert_stream_closed_error(self, e)
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/comm/tcp.py", line 143, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed)  local=tcp://127.0.0.1:36007 remote=tcp://127.0.0.1:48042>: TimeoutError: [Errno 110] Connection timed out
# 2025-11-05 15:32:45,156 - distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:36007
# Traceback (most recent call last):
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/tornado/iostream.py", line 861, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/tornado/iostream.py", line 1116, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [Errno 104] Connection reset by peer
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/worker.py", line 2075, in gather_dep
#     response = await get_data_from_worker(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/worker.py", line 2881, in get_data_from_worker
#     response = await send_recv(
#                ^^^^^^^^^^^^^^^^
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/core.py", line 1018, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/comm/tcp.py", line 237, in read
#     convert_stream_closed_error(self, e)
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/comm/tcp.py", line 143, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) Ephemeral Worker->Worker for gather local=tcp://127.0.0.1:48042 remote=tcp://127.0.0.1:36007>: ConnectionResetError: [Errno 104] Connection reset by peer
# 2025-11-05 15:44:35,919 - distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:42065
# Traceback (most recent call last):
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/tornado/iostream.py", line 861, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/tornado/iostream.py", line 1116, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [Errno 104] Connection reset by peer
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/worker.py", line 2075, in gather_dep
#     response = await get_data_from_worker(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/worker.py", line 2881, in get_data_from_worker
#     response = await send_recv(
#                ^^^^^^^^^^^^^^^^
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/core.py", line 1018, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/comm/tcp.py", line 237, in read
#     convert_stream_closed_error(self, e)
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/comm/tcp.py", line 143, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) Ephemeral Worker->Worker for gather local=tcp://127.0.0.1:44966 remote=tcp://127.0.0.1:42065>: ConnectionResetError: [Errno 104] Connection reset by peer
# 2025-11-05 15:44:35,918 - distributed.worker - ERROR - failed during get data with tcp://127.0.0.1:42065 -> tcp://127.0.0.1:45257
# Traceback (most recent call last):
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/tornado/iostream.py", line 861, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/tornado/iostream.py", line 1116, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# TimeoutError: [Errno 110] Connection timed out
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/worker.py", line 1797, in get_data
#     response = await comm.read(deserializers=serializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/comm/tcp.py", line 237, in read
#     convert_stream_closed_error(self, e)
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/comm/tcp.py", line 143, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed)  local=tcp://127.0.0.1:42065 remote=tcp://127.0.0.1:44966>: TimeoutError: [Errno 110] Connection timed out
# 2025-11-05 15:54:13,279 - distributed.worker - ERROR - failed during get data with tcp://127.0.0.1:40595 -> tcp://127.0.0.1:33407
# Traceback (most recent call last):
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/tornado/iostream.py", line 861, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/tornado/iostream.py", line 1116, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# TimeoutError: [Errno 110] Connection timed out
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/worker.py", line 1797, in get_data
#     response = await comm.read(deserializers=serializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/comm/tcp.py", line 237, in read
#     convert_stream_closed_error(self, e)
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/comm/tcp.py", line 143, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed)  local=tcp://127.0.0.1:40595 remote=tcp://127.0.0.1:53388>: TimeoutError: [Errno 110] Connection timed out
# 2025-11-05 15:56:09,145 - distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:40595
# Traceback (most recent call last):
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/tornado/iostream.py", line 861, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/tornado/iostream.py", line 1116, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [Errno 104] Connection reset by peer
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/worker.py", line 2075, in gather_dep
#     response = await get_data_from_worker(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/worker.py", line 2881, in get_data_from_worker
#     response = await send_recv(
#                ^^^^^^^^^^^^^^^^
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/core.py", line 1018, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/comm/tcp.py", line 237, in read
#     convert_stream_closed_error(self, e)
#   File "/home/tmiesse/miniforge3/envs/general/lib/python3.12/site-packages/distributed/comm/tcp.py", line 143, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) Ephemeral Worker->Worker for gather local=tcp://127.0.0.1:53388 remote=tcp://127.0.0.1:40595>: ConnectionResetError: [Errno 104] Connection reset by peer

# %%
years_all    = ds_all.time.dt.year.values
years_unique = np.unique(years_all)
nnode        = z.shape[1]

# %%
# compute annual maxima
annual_max = np.full((len(years_unique), nnode), np.nan)
for i, yr in enumerate(years_unique):
    mask = years_all == yr
    if mask.any():
        annual_max[i, :] = np.nanmax(z[mask, :], axis=0)

da_annual = xr.DataArray(
    annual_max,
    dims=('year','node'),
    coords={
        'year': years_unique,
        'node': ds_all.node,
        'x':     ('node', x_all),
        'y':     ('node', y_all),
    },
    name='annual_max_zeta'
)

# %%
da_annual.to_netcdf("/scratch/tmiesse/project/annual_max_zeta.nc")

# %%
da_annual = xr.open_dataset(
    "/scratch/tmiesse/project/annual_max_zeta.nc")

# %%
x_all = da_annual.x.values
y_all = da_annual.y.values

# %%
# ─── Apply change-point detection across nodes ────────────────────────────────
cp_da = xr.apply_ufunc(
    detect_cp_annual,
    da_annual,
    input_core_dims=[['year']],
    output_core_dims=[[]],
    vectorize=True,
    kwargs={'years_array': da_annual.year.values},
    dask='parallelized',
    output_dtypes=[float]
).rename('inflection_year')

# reattach spatial coordinates
cp_da = cp_da.assign_coords({
    'x': ('node', x_all),
    'y': ('node', y_all),
})

# ─── Save to NetCDF ───────────────────────────────────────────────────────────
ds_inf = cp_da.to_dataset()
outpath = '/scratch/tmiesse/project/inflection_annual2.nc'
ds_inf.to_netcdf(outpath)

# %%
outpath = '/scratch/tmiesse/project/inflection_annual2.nc'
ds_inf = xr.open_dataset(outpath)

# %%
# ─── Plot top‑4 inflection years on a polar map ───────────────────────────────
inf_years = ds_inf.inflection_year.values
lon, lat  = ds_inf.x.values, ds_inf.y.values

mask = ~np.isnan(inf_years)
yrs, cnts = np.unique(inf_years[mask].astype(int), return_counts=True)
top4     = np.sort(yrs[np.argsort(cnts)[-4:]])
bin_idx  = np.full_like(inf_years, -1, int)
for b, yr in enumerate(top4):
    bin_idx[inf_years == yr] = b
mask4 = bin_idx >= 0

cmap    = plt.get_cmap('tab10', len(top4))
bounds  = np.arange(len(top4)+1) - 0.5
norm    = mpl.colors.BoundaryNorm(bounds, len(top4))

fig = plt.figure(figsize=(7, 5))
ax  = plt.axes(projection=ccrs.NorthPolarStereo(central_longitude=-145))
ax.set_extent([-168, -140, 58, 71], crs=ccrs.PlateCarree())
ax.add_feature(cfeature.LAND,  facecolor='lightgray')
ax.add_feature(cfeature.OCEAN, facecolor='aliceblue')
ax.coastlines(resolution='10m', linewidth=0.5)
ax.gridlines(
    xlocs=np.arange(-180, -100, 5),
    ylocs=np.arange(50, 90, 3),
    draw_labels=False, linewidth=0.2,
    color='black', alpha=0.3, linestyle='--'
)
sc = ax.scatter(
    lon[mask4], lat[mask4],
    c=bin_idx[mask4], cmap=cmap, norm=norm,
    s=2.5, transform=ccrs.PlateCarree(), zorder=2
)
cax = fig.add_axes([0.85, 0.11, 0.02, 0.77])
cb  = fig.colorbar(
    mpl.cm.ScalarMappable(norm=norm, cmap=cmap),
    cax=cax, orientation='vertical',
    boundaries=bounds, ticks=np.arange(len(top4))
)
cb.set_ticklabels(top4.astype(int))
cb.set_label('Inflection Year')
plt.savefig(
    '/scratch/tmiesse/project/figures/inflection_map2.png',
    dpi=720, bbox_inches='tight', pad_inches=0.1
)
plt.show()

# %%
# ─── Stationarity tests (placeholders) ────────────────────────────────────────
# NOTE: arrays pre_stat, post_stat, pre_p_adf, etc. are initialized below—
#       fill them using test_stationarity before saving if needed.
years_arr = da_annual.year.values.astype(int)
nnode     = da_annual.sizes['node']

pre_stat   = np.full(nnode, False, dtype=bool)
post_stat  = np.full(nnode, False, dtype=bool)
pre_p_adf  = np.full(nnode, np.nan)
pre_p_kpss = np.full(nnode, np.nan)
post_p_adf = np.full(nnode, np.nan)
post_p_kpss= np.full(nnode, np.nan)

ds_stat = xr.Dataset({
    'pre_stationary':   (('node',), pre_stat),
    'post_stationary':  (('node',), post_stat),
    'pre_p_adf':        (('node',), pre_p_adf),
    'pre_p_kpss':       (('node',), pre_p_kpss),
    'post_p_adf':       (('node',), post_p_adf),
    'post_p_kpss':      (('node',), post_p_kpss),
}, coords={'x':('node', x_all), 'y':('node', y_all)})

ds_stat.to_netcdf('/scratch/tmiesse/project/inflection_stationarity2.nc')

# %%
ds_stat = xr.open_dataset(
    '/scratch/tmiesse/project/inflection_stationarity2.nc')

# %%
# === Parameters ===
alpha = 0.05  # significance level
min_samples = 5  # minimum non-NaN points to test
years_arr = da_annual.year.values.astype(int)  # e.g. [1980,...]
nyears = len(years_arr)
nnode = da_annual.sizes['node']
inf_years = xr.open_dataset('/scratch/tmiesse/project/inflection_annual2.nc')['inflection_year'].values

# === Containers ===
pre_stat_strict   = np.full(nnode, False, dtype=bool)
post_stat_strict  = np.full(nnode, False, dtype=bool)
pre_p_adf         = np.full(nnode, np.nan)
pre_p_kpss        = np.full(nnode, np.nan)
post_p_adf        = np.full(nnode, np.nan)
post_p_kpss       = np.full(nnode, np.nan)

pre_stat_loose    = np.full(nnode, False, dtype=bool)
post_stat_loose   = np.full(nnode, False, dtype=bool)

# === Helper test function ===
def compute_adf_kpss(arr):
    """Return (p_adf, p_kpss), with safe fallbacks."""
    with warnings.catch_warnings():
        warnings.simplefilter("ignore", HypothesisTestWarning)
        try:
            p_adf = adfuller(arr, autolag='AIC')[1]
        except Exception:
            p_adf = 1.0  # fail conservative
    with warnings.catch_warnings():
        warnings.simplefilter("ignore", HypothesisTestWarning)
        try:
            p_kpss = kpss(arr, regression='c', nlags='auto')[1]
        except Exception:
            p_kpss = 0.0  # fail conservative
    # clamp
    p_adf  = min(max(p_adf, 0.0), 1.0)
    p_kpss = min(max(p_kpss, 0.0), 1.0)
    return p_adf, p_kpss

# === Year to index map for inflection split ===
year_to_idx = {int(yr): idx for idx, yr in enumerate(years_arr)}

# === Loop over nodes ===
for i in range(nnode):
    cp_year = inf_years[i]
    if np.isnan(cp_year):
        continue
    cp_year = int(cp_year)
    cp_idx = year_to_idx.get(cp_year, None)
    if cp_idx is None or cp_idx == 0 or cp_idx >= nyears:
        continue

    # Pre-inflection segment
    pre_series = da_annual.values[:cp_idx, i]
    valid_pre = pre_series[np.isfinite(pre_series)]
    if valid_pre.size >= min_samples:
        p_adf_pre, p_kpss_pre = compute_adf_kpss(valid_pre)
        pre_p_adf[i] = p_adf_pre
        pre_p_kpss[i] = p_kpss_pre
        strict_pre = (p_adf_pre < alpha) and (p_kpss_pre > alpha)
        loose_pre  = (p_adf_pre < alpha) or (p_kpss_pre > alpha)
        pre_stat_strict[i] = strict_pre
        pre_stat_loose[i]  = loose_pre

    # Post-inflection segment (includes inflection year)
    post_series = da_annual.values[cp_idx:, i]
    valid_post = post_series[np.isfinite(post_series)]
    if valid_post.size >= min_samples:
        p_adf_post, p_kpss_post = compute_adf_kpss(valid_post)
        post_p_adf[i] = p_adf_post
        post_p_kpss[i] = p_kpss_post
        strict_post = (p_adf_post < alpha) and (p_kpss_post > alpha)
        loose_post  = (p_adf_post < alpha) or (p_kpss_post > alpha)
        post_stat_strict[i] = strict_post
        post_stat_loose[i]  = loose_post

# === Decide which mask to use: strict unless it yields zero hits ===
use_loose_pre = pre_stat_strict.sum() == 0
use_loose_post = post_stat_strict.sum() == 0

pre_stat_final  = pre_stat_loose if use_loose_pre else pre_stat_strict
post_stat_final = post_stat_loose if use_loose_post else post_stat_strict

# === Diagnostics ===
print("Pre-inflection stationarity (strict) count:", np.sum(pre_stat_strict))
print("Post-inflection stationarity (strict) count:", np.sum(post_stat_strict))
if use_loose_pre:
    print("Falling back to loose pre-inflection criterion; count:", np.sum(pre_stat_loose))
if use_loose_post:
    print("Falling back to loose post-inflection criterion; count:", np.sum(post_stat_loose))

# === Build and save dataset ===
ds_stat = xr.Dataset({
    'pre_stationary':   (('node',), pre_stat_final,  {'long_name': 'pre-inflection stationary?'}),
    'post_stationary':  (('node',), post_stat_final, {'long_name': 'post-inflection stationary?'}),
    'pre_p_adf':        (('node',), pre_p_adf,       {'long_name': 'ADF p-value (pre)'}),
    'pre_p_kpss':       (('node',), pre_p_kpss,      {'long_name': 'KPSS p-value (pre)'}),
    'post_p_adf':       (('node',), post_p_adf,      {'long_name': 'ADF p-value (post)'}),
    'post_p_kpss':      (('node',), post_p_kpss,     {'long_name': 'KPSS p-value (post)'}),
}, coords={
    'node': da_annual['node'].values,
    'x': ('node', x_all),
    'y': ('node', y_all),
})

out_stat_path = '/scratch/tmiesse/project/inflection_stationarity2.nc'
ds_stat.to_netcdf(out_stat_path)
print(f"Saved updated stationarity file to {out_stat_path}")
# Out:
# Pre-inflection stationarity (strict) count: 150744
# Post-inflection stationarity (strict) count: 103038
# Saved updated stationarity file to /scratch/tmiesse/project/inflection_stationarity2.nc

# %%
# ─── Parameters & prerequisites ───────────────────────────────────────────────
# Assumes YEARS, ds_all, z, x_all, y_all, inf_years are already defined
years_unique = np.array(list(YEARS))       # e.g. [1980, …, 2024]
nyears, nnode = len(years_unique), z.shape[1]

# ─── 1) Compute monthly maxima per node ───────────────────────────────────────
monthly_max = np.full((nyears, 12, nnode), np.nan)
for i, yr in enumerate(years_unique):
    mask_year = ds_all.time.dt.year == yr
    for m in range(1, 13):
        mask_month = mask_year & (ds_all.time.dt.month == m)
        if mask_month.any():
            monthly_max[i, m-1, :] = np.nanmax(z[mask_month, :], axis=0)

da_monthly = xr.DataArray(
    monthly_max,
    dims=('year','month','node'),
    coords={
        'year':  years_unique,
        'month': np.arange(1, 13),
        'node':  ds_all.node,
        'x':     ('node', x_all),
        'y':     ('node', y_all),
    },
    name='monthly_max_zeta'
)

# ─── 2) Prepare containers for return levels ─────────────────────────────────
return_periods = [10, 50, 100, 500]
rp_pre  = {T: np.full((12, nnode), np.nan) for T in return_periods}
rp_post = {T: np.full((12, nnode), np.nan) for T in return_periods}

# ─── 3) Loop over nodes, split at inflection, fit Gumbel, store ppf ────────
for i in range(nnode):
    cp_year = inf_years[i]
    if np.isnan(cp_year):
        continue

    # find the index of cp_year
    try:
        cp_idx = int(np.where(years_unique == cp_year)[0][0])
    except IndexError:
        continue
    if not (0 < cp_idx < nyears):
        continue

    for m in range(12):
        # Pre-inflection
        data_pre  = da_monthly[:cp_idx, m, i].values
        valid_pre = data_pre[np.isfinite(data_pre)]
        if len(valid_pre) >= 20:
            loc, scale = gumbel_r.fit(valid_pre)
            for T in return_periods:
                rp_pre[T][m, i] = gumbel_r.ppf(1 - 1/T, loc=loc, scale=scale)

        # Post-inflection
        data_post  = da_monthly[cp_idx:, m, i].values
        valid_post = data_post[np.isfinite(data_post)]
        if len(valid_post) >= 20:
            loc2, scale2 = gumbel_r.fit(valid_post)
            for T in return_periods:
                rp_post[T][m, i] = gumbel_r.ppf(1 - 1/T, loc=loc2, scale=scale2)

# ─── 4) Wrap into an xarray Dataset and save ─────────────────────────────────
data_vars = {}
for T in return_periods:
    data_vars[f'rp_pre_{T}']  = (('month','node'), rp_pre[T],
                                {'units':'m',
                                 'long_name':f'{T}-yr return level (pre)'})
    data_vars[f'rp_post_{T}'] = (('month','node'), rp_post[T],
                                {'units':'m',
                                 'long_name':f'{T}-yr return level (post)'})

ds_monthly_rp = xr.Dataset(
    data_vars,
    coords={
        'month': np.arange(1, 13),
        'node':  da_monthly.node,
        'x':     ('node', x_all),
        'y':     ('node', y_all),
    }
)

# %%
outpath = '/scratch/tmiesse/project/inflection_returnlevels_monthly3.nc'
ds_monthly_rp.to_netcdf(outpath)

# %%
outpath = '/scratch/tmiesse/project/inflection_returnlevels_monthly3.nc'
ds_monthly_rp = xr.open_dataset(outpath)

# %%
# ─── 6×6 Panel: Monthly Return Levels & ΔT ────────────────────────────────────
# 1) Load the dataset and pick a return period (e.g., 10‑yr)
ds      = xr.open_dataset('/scratch/tmiesse/project/inflection_returnlevels_monthly3.nc')
x, y    = ds['x'].values, ds['y'].values
T       = 100
da_pre  = ds[f'rp_pre_{T}']        # dims = (month, node)
da_post = ds[f'rp_post_{T}']
da_diff = (da_post - da_pre) / da_pre * 100

# 2) Colormap settings
bins_pp    = np.linspace(0, 3.5, 8)
cmap_pp    = plt.get_cmap('rainbow', len(bins_pp)-1)
norm_pp    = mpl.colors.BoundaryNorm(bins_pp, len(bins_pp)-1)
ticks_diff = np.arange(-40, 41, 10)
cmap_diff  = plt.get_cmap('coolwarm', len(ticks_diff)-1)
norm_diff  = mpl.colors.BoundaryNorm(ticks_diff, len(ticks_diff)-1)

# 3) Panel labels & row titles
n_panels     = 36
panel_labels = make_labels(n_panels)
row_titles   = [
    'Pre-Inflection', 'Pre-Inflection',
    'Post-Inflection', 'Post-Inflection',
    'ΔT',             'ΔT'
]

# 4) Figure setup: 6 rows × 6 cols of polar maps
fig, axes = plt.subplots(
    6, 6, figsize=(18, 18),
    subplot_kw={'projection': ccrs.NorthPolarStereo(central_longitude=-145)},
    gridspec_kw={'wspace':0.05, 'hspace':0.05}
)

panel_idx = 0
for row in range(6):
    block = row // 2   # 0=pre, 1=post, 2=diff
    for col in range(6):
        ax = axes[row, col]
        ax.set_extent([-169, -140, 58, 71], crs=ccrs.PlateCarree())
        ax.add_feature(cfeature.LAND,  facecolor='lightgray')
        ax.add_feature(cfeature.OCEAN, facecolor='aliceblue')
        ax.coastlines(resolution='10m', linewidth=0.1)
        ax.gridlines(
            xlocs=np.arange(-180, -100, 5),
            ylocs=np.arange(50, 90, 3),
            draw_labels=False, linewidth=0.2,
            color='black', alpha=0.3, linestyle='--'
        )

        # determine month and data for this panel
        month = (col + 1) + 6*(row % 2)  # 1–6 if row even, 7–12 if odd
        if block == 0:
            data, cmap, norm = da_pre.sel(month=month), cmap_pp, norm_pp
        elif block == 1:
            data, cmap, norm = da_post.sel(month=month), cmap_pp, norm_pp
        else:
            data, cmap, norm = da_diff.sel(month=month), cmap_diff, norm_diff

        arr = data.values
        mask = ~np.isnan(arr)
        ax.scatter(
            x[mask], y[mask], c=arr[mask],
            cmap=cmap, norm=norm,
            s=5, transform=ccrs.PlateCarree()
        )

        # month title and panel label
        ax.set_title(calendar.month_abbr[month], fontsize=10, pad=2)
        ax.text(
            0.02, 1.06, panel_labels[panel_idx],
            transform=ax.transAxes,
            fontsize=10, fontweight=None,
            va='top'
        )
        panel_idx += 1
        ax.set_xticks([]); ax.set_yticks([])

# 5) Row titles along left margin
for row in range(6):
    pos   = axes[row, 0].get_position()
    y_mid = 0.5 * (pos.y0 + pos.y1)
    fig.text(
        pos.x0 - 0.005, y_mid,
        row_titles[row],
        fontsize=12, fontweight='bold',
        rotation='vertical', va='center', ha='right'
    )

# 6) Shared colorbars
# Pre/Post
cax1 = fig.add_axes([0.91, 0.3725, 0.015, 0.505])
cb1  = fig.colorbar(
    mpl.cm.ScalarMappable(norm=norm_pp, cmap=cmap_pp),
    cax=cax1, orientation='vertical',
    boundaries=bins_pp, ticks=bins_pp
)
cb1.set_label('WSE [m at MSL]', fontsize=12)

# ΔT
cax2 = fig.add_axes([0.91, 0.113, 0.015, 0.2475])
cb2  = fig.colorbar(
    mpl.cm.ScalarMappable(norm=norm_diff, cmap=cmap_diff),
    cax=cax2, orientation='vertical',
    boundaries=ticks_diff, ticks=ticks_diff
)
cb2.set_label('% ΔT', fontsize=12)

#plt.suptitle(f'{T}-yr Return Levels by Month (6×6)', fontsize=16, y=0.92)
plt.savefig(
    '/scratch/tmiesse/project/figures/return_period_seasonal_50yr.png',
    dpi=300, bbox_inches='tight')
plt.show()

# %%
# ─── 2×6 Panel: Monthly Percent Differences (ΔT) ──────────────────────────────
import xarray as xr
import matplotlib.pyplot as plt
import matplotlib as mpl
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import calendar
import numpy as np

# 1) Load dataset
ds      = xr.open_dataset('/scratch/tmiesse/project/inflection_returnlevels_monthly3.nc')
x, y    = ds['x'].values, ds['y'].values
T       = 100
da_pre  = ds[f'rp_pre_{T}']
da_post = ds[f'rp_post_{T}']
da_diff = (da_post - da_pre) / da_pre * 100   # % difference

# 2) Colormap settings (only ΔT)
ticks_diff = np.arange(-40, 41, 10)
cmap_diff  = plt.get_cmap('coolwarm', len(ticks_diff)-1)
norm_diff  = mpl.colors.BoundaryNorm(ticks_diff, len(ticks_diff)-1)

# 3) Panel labels (12 panels total now)
panel_labels = [f"{chr(97+i)}." for i in range(12)]  # (a)...(l)

# 4) Figure setup: 2 rows × 6 cols
fig, axes = plt.subplots(
    2, 6, figsize=(18, 6),
    subplot_kw={'projection': ccrs.NorthPolarStereo(central_longitude=-145)},
    gridspec_kw={'wspace':0.05, 'hspace':0.05}
)

panel_idx = 0
for row in range(2):
    for col in range(6):
        ax = axes[row, col]
        ax.set_extent([-169, -140, 58, 71], crs=ccrs.PlateCarree())
        ax.add_feature(cfeature.LAND,  facecolor='lightgray')
        ax.add_feature(cfeature.OCEAN, facecolor='aliceblue')
        ax.coastlines(resolution='10m', linewidth=0.1)
        ax.gridlines(
            xlocs=np.arange(-180, -100, 5),
            ylocs=np.arange(50, 90, 3),
            draw_labels=False, linewidth=0.2,
            color='black', alpha=0.3, linestyle='--'
        )

        # month index: 1–6 on first row, 7–12 on second
        month = (col + 1) + 6*(row % 2)

        # plot ΔT
        data = da_diff.sel(month=month)
        arr = data.values
        mask = ~np.isnan(arr)
        ax.scatter(
            x[mask], y[mask], c=arr[mask],
            cmap=cmap_diff, norm=norm_diff,
            s=5, transform=ccrs.PlateCarree()
        )

        # month title and panel label
        ax.set_title(calendar.month_abbr[month], fontsize=10, pad=2)
        ax.text(
            0.02, 1.065, panel_labels[panel_idx],
            transform=ax.transAxes,
            fontsize=10, fontweight=None,
            va='top'
        )
        panel_idx += 1
        ax.set_xticks([]); ax.set_yticks([])

# 5) Shared colorbar for ΔT
cax = fig.add_axes([0.91, 0.125, 0.015, 0.7425])
cb  = fig.colorbar(
    mpl.cm.ScalarMappable(norm=norm_diff, cmap=cmap_diff),
    cax=cax, orientation='vertical',
    boundaries=ticks_diff, ticks=ticks_diff
)
cb.set_label('% ΔT', fontsize=12)

plt.savefig(
    '/scratch/tmiesse/project/figures/return_period_seasonal_diff_only.png',
    dpi=300, bbox_inches='tight')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[14], line 36
#      34 for row in range(1):
#      35     for col in range(2):
# ---> 36         ax = axes[0, col]
#      37         ax.set_extent([-169, -140, 58, 71], crs=ccrs.PlateCarree())
#      38         ax.add_feature(cfeature.LAND,  facecolor='lightgray')
#
# IndexError: too many indices for array: array is 1-dimensional, but 2 were indexed

# %%
# ─── 2×6 Panel: Monthly Percent Differences (ΔT) ──────────────────────────────
import xarray as xr
import matplotlib.pyplot as plt
import matplotlib as mpl
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import calendar
import numpy as np

# 1) Load dataset
ds      = xr.open_dataset('/scratch/tmiesse/project/inflection_returnlevels_monthly3.nc')
x, y    = ds['x'].values, ds['y'].values
T       = 100
da_pre  = ds[f'rp_pre_{T}']
da_post = ds[f'rp_post_{T}']
da_diff = (da_post - da_pre) / da_pre * 100   # % difference

# 2) Colormap settings (only ΔT)
ticks_diff = np.arange(-40, 41, 10)
cmap_diff  = plt.get_cmap('coolwarm', len(ticks_diff)-1)
norm_diff  = mpl.colors.BoundaryNorm(ticks_diff, len(ticks_diff)-1)

# 3) Panel labels (12 panels total now)
panel_labels = [f"{chr(97+i)}." for i in range(12)]  # (a)...(l)

# 4) Figure setup: 2 rows × 6 cols
fig, axes = plt.subplots(
    1, 3, figsize=(10, 4),
    subplot_kw={'projection': ccrs.NorthPolarStereo(central_longitude=-145)},
    gridspec_kw={'wspace':0.05, 'hspace':0.05}
)

panel_idx = 0
#for row in range(2):
month = [9,10,11]
for col in [0,1,2]:
    ax = axes[col]
    ax.set_extent([-169, -140, 58, 71], crs=ccrs.PlateCarree())
    ax.add_feature(cfeature.LAND,  facecolor='lightgray')
    ax.add_feature(cfeature.OCEAN, facecolor='aliceblue')
    ax.coastlines(resolution='10m', linewidth=0.1)
    ax.gridlines(
        xlocs=np.arange(-180, -100, 5),
        ylocs=np.arange(50, 90, 3),
        draw_labels=False, linewidth=0.2,
        color='black', alpha=0.3, linestyle='--'
    )

    # month index: 1–6 on first row, 7–12 on second
    #month = (col + 1) + 6*(row % 2)

    # plot ΔT

    data = da_diff.sel(month=month[col])
    arr = data.values
    mask = ~np.isnan(arr)
    ax.scatter(
        x[mask], y[mask], c=arr[mask],
        cmap=cmap_diff, norm=norm_diff,
        s=5, transform=ccrs.PlateCarree()
    )

    # month title and panel label
    ax.set_title(calendar.month_abbr[month[col]], fontsize=10, pad=2)
    ax.text(
        0.02, 1.065, panel_labels[panel_idx],
        transform=ax.transAxes,
        fontsize=10, fontweight=None,
        va='top'
    )
    panel_idx += 1
    ax.set_xticks([]); ax.set_yticks([])

# 5) Shared colorbar for ΔT
cax = fig.add_axes([0.91, 0.2, 0.015, 0.59])
cb  = fig.colorbar(
    mpl.cm.ScalarMappable(norm=norm_diff, cmap=cmap_diff),
    cax=cax, orientation='vertical',
    boundaries=ticks_diff, ticks=ticks_diff
)
cb.set_label('% ΔT', fontsize=12)

plt.savefig(
    '/scratch/tmiesse/project/figures/return_period_fall_diff4present.png',
    dpi=300, bbox_inches='tight')
plt.show()

# %%
da_pre  = ds[f'rp_pre_{T}']
da_post = ds[f'rp_post_{T}']

# %%
da_pre.to_pandas()
# Out:
# node   0         1         2       3       4       5         6       7       \
# month
# 1         NaN  0.022606  0.009895     NaN     NaN     NaN  0.015437     NaN
# 2         NaN  0.020275  0.016726     NaN     NaN     NaN  0.013251     NaN
# 3         NaN  0.024789  0.011005     NaN     NaN     NaN  0.016410     NaN
# 4         NaN  0.011907  0.007657     NaN     NaN     NaN  0.007023     NaN
# 5         NaN  0.008158  0.004746     NaN     NaN     NaN  0.005505     NaN
# 6         NaN  0.003911  0.003670     NaN     NaN     NaN  0.002199     NaN
# 7         NaN  0.003691  0.003961     NaN     NaN     NaN  0.002358     NaN
# 8         NaN  0.006921  0.007084     NaN     NaN     NaN  0.003935     NaN
# 9         NaN  0.008779  0.007138     NaN     NaN     NaN  0.004694     NaN
# 10        NaN  0.013974  0.009799     NaN     NaN     NaN  0.007616     NaN
# 11        NaN  0.018803  0.010902     NaN     NaN     NaN  0.011285     NaN
# 12        NaN  0.017960  0.009890     NaN     NaN     NaN  0.010628     NaN
#
# node   8         9       ...    182564    182565    182566    182567  \
# month                    ...
# 1         NaN  0.014997  ...  0.469047  0.453382  0.450607  0.465783
# 2         NaN  0.025819  ...  0.424116  0.413071  0.412107  0.421988
# 3         NaN  0.015060  ...  0.463255  0.447873  0.444584  0.460316
# 4         NaN  0.010330  ...  0.464302  0.449845  0.445483  0.461554
# 5         NaN  0.007115  ...  0.509905  0.502117  0.498908  0.508994
# 6         NaN  0.004842  ...  0.520384  0.513296  0.511308  0.519112
# 7         NaN  0.006215  ...  0.515133  0.508524  0.506748  0.514588
# 8         NaN  0.011899  ...  0.542499  0.538175  0.537757  0.542510
# 9         NaN  0.011346  ...  0.650092  0.643388  0.642342  0.649707
# 10        NaN  0.014623  ...  0.631783  0.624372  0.623656  0.630450
# 11        NaN  0.016308  ...  0.771156  0.759800  0.757680  0.769227
# 12        NaN  0.015063  ...  0.770832  0.759958  0.757891  0.768537
#
# node     182568    182569    182570    182571    182572    182573
# month
# 1      0.457201  0.473544  0.467923  0.464741  0.474237  0.473720
# 2      0.415260  0.428226  0.425323  0.423489  0.429753  0.430468
# 3      0.451078  0.466997  0.461479  0.458319  0.467701  0.466734
# 4      0.452628  0.468031  0.462426  0.458859  0.468176  0.467173
# 5      0.503505  0.513343  0.512198  0.510208  0.515433  0.516859
# 6      0.514312  0.522572  0.519703  0.518371  0.522698  0.522483
# 7      0.509978  0.515184  0.515269  0.512362  0.515838  0.515672
# 8      0.538852  0.542639  0.544762  0.542568  0.544051  0.544911
# 9      0.645017  0.652235  0.653654  0.650839  0.654193  0.655677
# 10     0.626106  0.634134  0.632302  0.630600  0.634903  0.635327
# 11     0.762298  0.775106  0.771533  0.769053  0.776110  0.776388
# 12     0.762516  0.773098  0.768780  0.766383  0.772998  0.772132
#
# [12 rows x 182574 columns]

# %%
file = pd.DataFrame({'x':x,'y':y,'jan_pre':da_pre.sel(month=1).values,
                     'jan_post':da_post.sel(month=1).values,
                     'feb_pre':da_pre.sel(month=2).values,
                     'feb_post':da_post.sel(month=2).values,
                     'mar_pre':da_pre.sel(month=3).values,
                     'mar_post':da_post.sel(month=3).values,
                     'apr_pre':da_pre.sel(month=4).values,'apr_post':da_post.sel(month=4).values,
                     'may_pre':da_pre.sel(month=5).values,'may_post':da_post.sel(month=5).values,
                     'jun_pre':da_pre.sel(month=6).values,'jun_post':da_post.sel(month=6).values,
                     'jul_pre':da_pre.sel(month=7).values,'jul_post':da_post.sel(month=7).values,
                     'aug_pre':da_pre.sel(month=8).values,'aug_post':da_post.sel(month=8).values,
                     'sep_pre':da_pre.sel(month=9).values,'sep_post':da_post.sel(month=9).values,
                     'oct_pre':da_pre.sel(month=10).values,'oct_post':da_post.sel(month=10).values,
                     'nov_pre':da_pre.sel(month=11).values,'nov_post':da_post.sel(month=11).values,
                     'dec_pre':da_pre.sel(month=12).values,'dec_post':da_post.sel(month=12).values,
                    })
file.to_csv('/scratch/tmiesse/project/monthly_100yr.csv',index=False)

# %%
da_annual
# Out:
# <xarray.Dataset> Size: 70MB
# Dimensions:          (year: 45, node: 182574)
# Coordinates:
#   * year             (year) int64 360B 1980 1981 1982 1983 ... 2022 2023 2024
#   * node             (node) int64 1MB 0 1 2 3 4 ... 182570 182571 182572 182573
#     x                (node) float64 1MB -158.1 -158.1 -158.1 ... -160.3 -160.2
#     y                (node) float64 1MB 58.94 58.95 58.96 ... 66.41 66.42 66.41
# Data variables:
#     annual_max_zeta  (year, node) float64 66MB ...

# %%
file = pd.DataFrame({'x':x_all,'y':y_all,'1980':da_annual.sel(year=1980).values,
                     '1981':da_annual.sel(year=1981).values,
                     '1982':da_annual.sel(year=1982).values,
                     '1983':da_annual.sel(year=1983).values,
                     '1984':da_annual.sel(year=1984).values,
                     '1985':da_annual.sel(year=1985).values,
                     '1986':da_annual.sel(year=1986).values,
                     '1987':da_annual.sel(year=1987).values,
                     '1988':da_annual.sel(year=1988).values,
                     '1989':da_annual.sel(year=1989).values,
                     '1990':da_annual.sel(year=1990).values,
                     '1991':da_annual.sel(year=1991).values,
                     '1992':da_annual.sel(year=1992).values,
                     '1993':da_annual.sel(year=1993).values,
                     '1994':da_annual.sel(year=1994).values,
                     '1995':da_annual.sel(year=1995).values,
                     '1996':da_annual.sel(year=1996).values,
                     '1997':da_annual.sel(year=1997).values,
                     '1998':da_annual.sel(year=1998).values,
                     '1999':da_annual.sel(year=1999).values,
                     '2000':da_annual.sel(year=2000).values,
                     '2001':da_annual.sel(year=2001).values,
                     '2002':da_annual.sel(year=2002).values,
                     '2003':da_annual.sel(year=2003).values,
                     '2004':da_annual.sel(year=2004).values,
                     '2005':da_annual.sel(year=2005).values,
                     '2006':da_annual.sel(year=2006).values,
                     '2007':da_annual.sel(year=2007).values,
                     '2008':da_annual.sel(year=2008).values,
                     '2009':da_annual.sel(year=2009).values,
                     '2010':da_annual.sel(year=2010).values,
                     '2011':da_annual.sel(year=2011).values,
                     '2012':da_annual.sel(year=2012).values,
                     '2013':da_annual.sel(year=2013).values,
                     '2014':da_annual.sel(year=2014).values,
                     '2015':da_annual.sel(year=2015).values,
                     '2016':da_annual.sel(year=2016).values,
                     '2017':da_annual.sel(year=2017).values,
                     '2018':da_annual.sel(year=2018).values,
                     '2019':da_annual.sel(year=2019).values,
                     '2020':da_annual.sel(year=2020).values,
                     '2021':da_annual.sel(year=2021).values,
                     '2022':da_annual.sel(year=2022).values,
                     '2023':da_annual.sel(year=2023).values,
                     '2024':da_annual.sel(year=2024).values,
                    })
file.to_csv('/scratch/tmiesse/project/annual_max_zeta.csv',index=False)
# Out:
# 2025-11-06 11:42:42,603 - distributed.worker - WARNING - Scheduler was unaware of this worker; shutting down.
# 2025-11-06 11:42:50,898 - distributed.worker - WARNING - Scheduler was unaware of this worker; shutting down.
# 2025-11-06 11:42:57,172 - distributed.worker - WARNING - Scheduler was unaware of this worker; shutting down.
# 2025-11-06 11:42:59,273 - distributed.worker - WARNING - Scheduler was unaware of this worker; shutting down.
# 2025-11-06 11:43:03,449 - distributed.worker - WARNING - Scheduler was unaware of this worker; shutting down.
# 2025-11-06 11:43:11,711 - distributed.worker - WARNING - Scheduler was unaware of this worker; shutting down.
# 2025-11-06 11:43:15,823 - distributed.worker - WARNING - Scheduler was unaware of this worker; shutting down.
# 2025-11-06 11:43:17,924 - distributed.worker - WARNING - Scheduler was unaware of this worker; shutting down.
# 2025-11-06 11:43:20,012 - distributed.worker - WARNING - Scheduler was unaware of this worker; shutting down.
# 2025-11-06 11:43:22,073 - distributed.worker - WARNING - Scheduler was unaware of this worker; shutting down.
# 2025-11-06 11:43:26,224 - distributed.worker - WARNING - Scheduler was unaware of this worker; shutting down.
# 2025-11-06 11:43:26,238 - distributed.worker - WARNING - Scheduler was unaware of this worker; shutting down.
# 2025-11-06 11:43:30,598 - distributed.worker - WARNING - Scheduler was unaware of this worker; shutting down.
# 2025-11-06 11:43:36,574 - distributed.worker - WARNING - Scheduler was unaware of this worker; shutting down.
# 2025-11-06 11:43:38,683 - distributed.worker - WARNING - Scheduler was unaware of this worker; shutting down.
# 2025-11-06 11:43:42,826 - distributed.worker - WARNING - Scheduler was unaware of this worker; shutting down.
# 2025-11-06 11:43:46,974 - distributed.worker - WARNING - Scheduler was unaware of this worker; shutting down.
# 2025-11-06 11:43:51,176 - distributed.worker - WARNING - Scheduler was unaware of this worker; shutting down.
# 2025-11-06 11:43:55,361 - distributed.worker - WARNING - Scheduler was unaware of this worker; shutting down.
# 2025-11-06 11:44:01,569 - distributed.worker - WARNING - Scheduler was unaware of this worker; shutting down.
# 2025-11-06 11:44:05,705 - distributed.worker - WARNING - Scheduler was unaware of this worker; shutting down.
# 2025-11-06 11:44:09,828 - distributed.worker - WARNING - Scheduler was unaware of this worker; shutting down.
# 2025-11-06 11:44:13,913 - distributed.worker - WARNING - Scheduler was unaware of this worker; shutting down.
# 2025-11-06 11:44:15,958 - distributed.worker - WARNING - Scheduler was unaware of this worker; shutting down.
# 2025-11-06 11:44:17,993 - distributed.worker - WARNING - Scheduler was unaware of this worker; shutting down.
# 2025-11-06 11:44:22,081 - distributed.worker - WARNING - Scheduler was unaware of this worker; shutting down.
# 2025-11-06 11:44:30,301 - distributed.worker - WARNING - Scheduler was unaware of this worker; shutting down.
# 2025-11-06 11:44:36,403 - distributed.worker - WARNING - Scheduler was unaware of this worker; shutting down.
# 2025-11-06 11:44:40,502 - distributed.worker - WARNING - Scheduler was unaware of this worker; shutting down.
# 2025-11-06 11:44:44,576 - distributed.worker - WARNING - Scheduler was unaware of this worker; shutting down.
# 2025-11-06 11:44:48,721 - distributed.worker - WARNING - Scheduler was unaware of this worker; shutting down.
# 2025-11-06 11:44:50,800 - distributed.worker - WARNING - Scheduler was unaware of this worker; shutting down.
# 2025-11-06 11:44:54,938 - distributed.worker - WARNING - Scheduler was unaware of this worker; shutting down.
# 2025-11-06 11:45:03,158 - distributed.worker - WARNING - Scheduler was unaware of this worker; shutting down.
# 2025-11-06 11:45:09,435 - distributed.worker - WARNING - Scheduler was unaware of this worker; shutting down.
# 2025-11-06 11:45:13,499 - distributed.worker - WARNING - Scheduler was unaware of this worker; shutting down.
# 2025-11-06 11:45:17,603 - distributed.worker - WARNING - Scheduler was unaware of this worker; shutting down.
# 2025-11-06 11:45:24,136 - distributed.worker - WARNING - Scheduler was unaware of this worker; shutting down.
# 2025-11-06 11:45:29,954 - distributed.worker - WARNING - Scheduler was unaware of this worker; shutting down.
# 2025-11-06 11:45:34,083 - distributed.worker - WARNING - Scheduler was unaware of this worker; shutting down.
# 2025-11-06 11:45:38,228 - distributed.worker - WARNING - Scheduler was unaware of this worker; shutting down.
# 2025-11-06 11:45:40,330 - distributed.worker - WARNING - Scheduler was unaware of this worker; shutting down.
# 2025-11-06 11:45:42,376 - distributed.worker - WARNING - Scheduler was unaware of this worker; shutting down.
# 2025-11-06 11:45:44,468 - distributed.worker - WARNING - Scheduler was unaware of this worker; shutting down.
# 2025-11-06 11:45:46,562 - distributed.worker - WARNING - Scheduler was unaware of this worker; shutting down.
# 2025-11-06 11:49:19,335 - distributed.core - INFO - Connection to tcp://127.0.0.1:43665 has been closed.
# 2025-11-06 11:49:19,336 - distributed.core - INFO - Connection to tcp://127.0.0.1:43665 has been closed.
# 2025-11-06 11:49:19,336 - distributed.core - INFO - Connection to tcp://127.0.0.1:43665 has been closed.
# 2025-11-06 11:49:19,337 - distributed.core - INFO - Connection to tcp://127.0.0.1:43665 has been closed.
# 2025-11-06 11:49:19,337 - distributed.core - INFO - Connection to tcp://127.0.0.1:43665 has been closed.
# 2025-11-06 11:49:19,337 - distributed.core - INFO - Connection to tcp://127.0.0.1:43665 has been closed.
# 2025-11-06 11:49:19,337 - distributed.core - INFO - Connection to tcp://127.0.0.1:43665 has been closed.
# 2025-11-06 11:49:19,337 - distributed.core - INFO - Connection to tcp://127.0.0.1:43665 has been closed.
# 2025-11-06 11:49:19,338 - distributed.core - INFO - Connection to tcp://127.0.0.1:43665 has been closed.
# 2025-11-06 11:49:19,338 - distributed.core - INFO - Connection to tcp://127.0.0.1:43665 has been closed.
# 2025-11-06 11:49:19,339 - distributed.core - INFO - Connection to tcp://127.0.0.1:43665 has been closed.
# 2025-11-06 11:49:19,339 - distributed.core - INFO - Connection to tcp://127.0.0.1:43665 has been closed.
# 2025-11-06 11:49:19,339 - distributed.core - INFO - Connection to tcp://127.0.0.1:43665 has been closed.
# 2025-11-06 11:49:19,339 - distributed.core - INFO - Connection to tcp://127.0.0.1:43665 has been closed.
# 2025-11-06 11:49:19,340 - distributed.core - INFO - Connection to tcp://127.0.0.1:43665 has been closed.
# 2025-11-06 11:49:19,341 - distributed.core - INFO - Connection to tcp://127.0.0.1:43665 has been closed.
# 2025-11-06 11:49:19,341 - distributed.core - INFO - Connection to tcp://127.0.0.1:43665 has been closed.
# 2025-11-06 11:49:19,341 - distributed.core - INFO - Connection to tcp://127.0.0.1:43665 has been closed.
# 2025-11-06 11:49:19,342 - distributed.core - INFO - Connection to tcp://127.0.0.1:43665 has been closed.
# 2025-11-06 11:49:19,342 - distributed.core - INFO - Connection to tcp://127.0.0.1:43665 has been closed.
# 2025-11-06 11:49:19,342 - distributed.core - INFO - Connection to tcp://127.0.0.1:43665 has been closed.
# 2025-11-06 11:49:19,343 - distributed.core - INFO - Connection to tcp://127.0.0.1:43665 has been closed.
# 2025-11-06 11:49:19,343 - distributed.core - INFO - Connection to tcp://127.0.0.1:43665 has been closed.
# 2025-11-06 11:49:19,343 - distributed.core - INFO - Connection to tcp://127.0.0.1:43665 has been closed.
# 2025-11-06 11:49:19,344 - distributed.core - INFO - Connection to tcp://127.0.0.1:43665 has been closed.
# 2025-11-06 11:49:19,344 - distributed.core - INFO - Connection to tcp://127.0.0.1:43665 has been closed.
# 2025-11-06 11:49:19,345 - distributed.core - INFO - Connection to tcp://127.0.0.1:43665 has been closed.
# 2025-11-06 11:49:19,345 - distributed.core - INFO - Connection to tcp://127.0.0.1:43665 has been closed.
# 2025-11-06 11:49:19,345 - distributed.core - INFO - Connection to tcp://127.0.0.1:43665 has been closed.
# 2025-11-06 11:49:19,346 - distributed.core - INFO - Connection to tcp://127.0.0.1:43665 has been closed.
# 2025-11-06 11:49:19,346 - distributed.core - INFO - Connection to tcp://127.0.0.1:43665 has been closed.
# 2025-11-06 11:49:19,346 - distributed.core - INFO - Connection to tcp://127.0.0.1:43665 has been closed.
# 2025-11-06 11:49:19,346 - distributed.core - INFO - Connection to tcp://127.0.0.1:43665 has been closed.
# 2025-11-06 11:49:19,347 - distributed.core - INFO - Connection to tcp://127.0.0.1:43665 has been closed.
# 2025-11-06 11:49:19,347 - distributed.core - INFO - Connection to tcp://127.0.0.1:43665 has been closed.
# 2025-11-06 11:49:19,347 - distributed.core - INFO - Connection to tcp://127.0.0.1:43665 has been closed.
# 2025-11-06 11:49:19,348 - distributed.core - INFO - Connection to tcp://127.0.0.1:43665 has been closed.
# 2025-11-06 11:49:19,348 - distributed.core - INFO - Connection to tcp://127.0.0.1:43665 has been closed.
# 2025-11-06 11:49:19,348 - distributed.core - INFO - Connection to tcp://127.0.0.1:43665 has been closed.
# 2025-11-06 11:49:19,348 - distributed.core - INFO - Connection to tcp://127.0.0.1:43665 has been closed.
# 2025-11-06 11:49:19,348 - distributed.core - INFO - Connection to tcp://127.0.0.1:43665 has been closed.
# 2025-11-06 11:49:19,350 - distributed.core - INFO - Connection to tcp://127.0.0.1:43665 has been closed.
# 2025-11-06 11:49:19,354 - distributed.core - INFO - Connection to tcp://127.0.0.1:43665 has been closed.
# 2025-11-06 11:49:19,357 - distributed.core - INFO - Connection to tcp://127.0.0.1:43665 has been closed.
# 2025-11-06 11:49:19,359 - distributed.core - INFO - Connection to tcp://127.0.0.1:43665 has been closed.
# 2025-11-06 11:49:21,338 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2025-11-06 11:49:21,338 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2025-11-06 11:49:21,339 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2025-11-06 11:49:21,340 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2025-11-06 11:49:21,341 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2025-11-06 11:49:21,341 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2025-11-06 11:49:21,342 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2025-11-06 11:49:21,343 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2025-11-06 11:49:21,344 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2025-11-06 11:49:21,344 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2025-11-06 11:49:21,346 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2025-11-06 11:49:21,346 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2025-11-06 11:49:21,347 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2025-11-06 11:49:21,347 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2025-11-06 11:49:21,348 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2025-11-06 11:49:21,348 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2025-11-06 11:49:21,348 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2025-11-06 11:49:21,349 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2025-11-06 11:49:21,349 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2025-11-06 11:49:21,350 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2025-11-06 11:49:21,351 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2025-11-06 11:49:21,353 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2025-11-06 11:49:21,356 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2025-11-06 11:49:21,360 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2025-11-06 11:49:21,372 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2025-11-06 11:49:21,404 - distributed.nanny - ERROR - Worker process died unexpectedly

# %%
use_stationarity = True  # set False to bypass pre/post stationary gating for debugging
min_samples = 20        # original threshold
return_periods = [10, 50, 100, 500]

# === Load inputs ===
ds_stat   = xr.open_dataset('/scratch/tmiesse/project/inflection_stationarity2.nc')
pre_stat  = ds_stat['pre_stationary'].values
post_stat = ds_stat['post_stationary'].values

ds_inf    = xr.open_dataset('/scratch/tmiesse/project/inflection_annual2.nc')
inf_years = ds_inf['inflection_year'].values  # (node,)

# da_annual, x_all, y_all, years_unique must already be in scope
years_unique = da_annual['year'].values.astype(int)
nnode = da_annual.sizes['node']
nyears = len(years_unique)

# helper: map year -> index
year_to_idx = {int(yr): idx for idx, yr in enumerate(years_unique)}

# === Prepare output arrays ===
rp_pre = {T: np.full(nnode, np.nan) for T in return_periods}
rp_post = {T: np.full(nnode, np.nan) for T in return_periods}

# === Counters for diagnostics ===
count_inf_valid = 0
count_pre_sample = 0
count_post_sample = 0
count_pre_stationary = 0
count_post_stationary = 0
count_pre_fitted = 0
count_post_fitted = 0

for i in range(nnode):
    cp_year = inf_years[i]
    if np.isnan(cp_year):
        continue
    cp_year = int(cp_year)
    cp_idx = year_to_idx.get(cp_year, None)
    if cp_idx is None or cp_idx == 0 or cp_idx >= nyears:
        continue
    count_inf_valid += 1

    # Pre-inflection slice and check
    data_pre = da_annual.annual_max_zeta.values[:cp_idx, i]
    valid_pre = data_pre[np.isfinite(data_pre)]
    has_pre_sample = valid_pre.size >= min_samples
    if has_pre_sample:
        count_pre_sample += 1
    if use_stationarity and pre_stat[i]:
        count_pre_stationary += 1
    if has_pre_sample and (not use_stationarity or pre_stat[i]):
        # attempt fit
        try:
            loc, scale = gumbel_r.fit(valid_pre)
            for T in return_periods:
                rp_pre[T][i] = gumbel_r.ppf(1 - 1 / T, loc=loc, scale=scale)
            count_pre_fitted += 1
        except Exception:
            # fit failed — leave NaNs
            pass

    # Post-inflection
    data_post = da_annual.annual_max_zeta.values[cp_idx:, i]
    valid_post = data_post[np.isfinite(data_post)]
    has_post_sample = valid_post.size >= min_samples
    if has_post_sample:
        count_post_sample += 1
    if use_stationarity and post_stat[i]:
        count_post_stationary += 1
    if has_post_sample and (not use_stationarity or post_stat[i]):
        try:
            loc2, scale2 = gumbel_r.fit(valid_post)
            for T in return_periods:
                rp_post[T][i] = gumbel_r.ppf(1 - 1 / T, loc=loc2, scale=scale2)
            count_post_fitted += 1
        except Exception:
            pass

# === Diagnostic summary ===
print("=== Annual return level diagnostics ===")
print(f"Nodes with valid inflection split: {count_inf_valid}/{nnode}")
print(f"Nodes with enough pre-inflection samples: {count_pre_sample}")
print(f"Nodes with enough post-inflection samples: {count_post_sample}")
if use_stationarity:
    print(f"Nodes pre-stationary flagged: {count_pre_stationary}")
    print(f"Nodes post-stationary flagged: {count_post_stationary}")
print(f"Nodes with successful pre-inflection fits: {count_pre_fitted}")
print(f"Nodes with successful post-inflection fits: {count_post_fitted}")

# === Assemble dataset ===
ds_out = xr.Dataset({
    'rp_pre_10':  (('node',), rp_pre[10],  {'units':'m','long_name':'10-yr return level (pre)'}),
    'rp_pre_50':  (('node',), rp_pre[50],  {'units':'m','long_name':'50-yr return level (pre)'}),
    'rp_pre_100': (('node',), rp_pre[100], {'units':'m','long_name':'100-yr return level (pre)'}),
    'rp_pre_500': (('node',), rp_pre[500], {'units':'m','long_name':'500-yr return level (pre)'}),
    'rp_post_10':  (('node',), rp_post[10],  {'units':'m','long_name':'10-yr return level (post)'}),
    'rp_post_50':  (('node',), rp_post[50],  {'units':'m','long_name':'50-yr return level (post)'}),
    'rp_post_100': (('node',), rp_post[100], {'units':'m','long_name':'100-yr return level (post)'}),
    'rp_post_500': (('node',), rp_post[500], {'units':'m','long_name':'500-yr return level (post)'}),
}, coords={
    'node': da_annual['node'].values,
    'x':    ('node', x_all),
    'y':    ('node', y_all),
})

# === Save ===
outpath = '/scratch/tmiesse/project/inflection_returnlevels_annual3.nc'
ds_out.to_netcdf(outpath, format='NETCDF4', engine='h5netcdf')
print(f"Saved annual return levels to: {outpath}")
# Out:
# === Annual return level diagnostics ===
# Nodes with valid inflection split: 182469/182574
# Nodes with enough pre-inflection samples: 172649
# Nodes with enough post-inflection samples: 55144
# Nodes pre-stationary flagged: 150744
# Nodes post-stationary flagged: 103038
# Nodes with successful pre-inflection fits: 147772
# Nodes with successful post-inflection fits: 39224
# Saved annual return levels to: /scratch/tmiesse/project/inflection_returnlevels_annual3.nc

# %%
# ─── 3×3 panel maps of return levels & percent differences ───────────────────
outpath = '/scratch/tmiesse/project/inflection_returnlevels_annual3.nc'
ds_rp = xr.open_dataset(outpath, engine='h5netcdf')
ds_rp = ds_out
x, y = ds_rp.x.values, ds_rp.y.values

# Prepare fields for T10, T50, T100
fields_pre = [
    (r'Pre-Inflection $T_{10}$',  ds_rp.rp_pre_10.values),
    (r'Pre-Inflection $T_{50}$',  ds_rp.rp_pre_50.values),
    (r'Pre-Inflection $T_{100}$', ds_rp.rp_pre_100.values),
]
fields_post = [
    (r'Post-Inflection $T_{10}$',  ds_rp.rp_post_10.values),
    (r'Post-Inflection $T_{50}$',  ds_rp.rp_post_50.values),
    (r'Post-Inflection $T_{100}$', ds_rp.rp_post_100.values),
]

# Compute percent differences
fields_diff = []
for (lbl_pre, arr_pre), (lbl_post, arr_post) in zip(fields_pre, fields_post):
    pct = (arr_post - arr_pre) / arr_pre * 100
    Tn = lbl_pre.split('$T_{')[-1].strip('}$')
    fields_diff.append((rf'$\Delta T_{{{Tn}}}$', pct))

all_fields = fields_pre + fields_post + fields_diff
labels     = make_labels(len(all_fields))

# Colormap setup for pre/post
bins_pp = np.linspace(0, 3.5, 8)
cmap_pp = plt.get_cmap('rainbow', len(bins_pp)-1)
norm_pp = mpl.colors.BoundaryNorm(bins_pp, len(bins_pp)-1)

# Colormap for percent diff

ticks_diff = np.arange(-40, 41, 10)
cmap_diff  = plt.get_cmap('coolwarm', len(ticks_diff)-1)
norm_diff  = mpl.colors.BoundaryNorm(ticks_diff, len(ticks_diff)-1)
# Create 3×3 map panel
fig, axes = plt.subplots(
    3, 3, figsize=(12, 12),
    subplot_kw={'projection': ccrs.NorthPolarStereo(central_longitude=-145)},
    gridspec_kw={
        'left':   0.02, 'right':  0.78,
        'top':    0.99, 'bottom': 0.01,
        'wspace': 0.01, 'hspace': -0.4,
    }
)

for idx, ax in enumerate(axes.flat):
    title, data = all_fields[idx]
    ax.set_extent([-169, -140, 58, 71], crs=ccrs.PlateCarree())
    ax.add_feature(cfeature.LAND,  facecolor='lightgray')
    ax.add_feature(cfeature.OCEAN, facecolor='aliceblue')
    ax.coastlines(resolution='10m', linewidth=0.1)
    ax.gridlines(
        xlocs=np.arange(-180, -100, 5),
        ylocs=np.arange( 50,   90, 3),
        draw_labels=False, linewidth=0.2,
        color='black', alpha=0.3, linestyle='--'
    )

    mask = ~np.isnan(data)
    cmap, norm = (cmap_pp, norm_pp) if idx < 6 else (cmap_diff, norm_diff)
    ax.scatter(
        x[mask], y[mask],
        c=data[mask], cmap=cmap, norm=norm,
        s=5, transform=ccrs.PlateCarree()
    )

    ax.set_title(title, fontsize=11, pad=2)
    ax.text(
        0.02, 1.05, labels[idx],
        transform=ax.transAxes,
        fontsize=10, va='top'
    )

# Shared colorbar for pre/post rows
cax1 = fig.add_axes([0.80, 0.385, 0.015, 0.50])
cb1  = fig.colorbar(
    mpl.cm.ScalarMappable(norm=norm_pp, cmap=cmap_pp),
    cax=cax1, orientation='vertical',
    boundaries=bins_pp, ticks=bins_pp
)
cb1.set_label('WSE [m at MSL]', fontsize=12)

# Shared colorbar for percent‑diff row
cax2 = fig.add_axes([0.80, 0.115, 0.015, 0.235])
cb2  = fig.colorbar(
    mpl.cm.ScalarMappable(norm=norm_diff, cmap=cmap_diff),
    cax=cax2, orientation='vertical',
    ticks=ticks_diff
)
#cb2.set_ticklabels([f"{t:.0f}%" for t in ticks_diff])
cb2.set_label(r'$\Delta T$ [%]', fontsize=12)

plt.savefig(
    '/scratch/tmiesse/project/figures/return_period2.png',
    dpi=720, bbox_inches='tight', pad_inches=0.1
)
plt.show()

# %%
# ─── 3×3 panel maps of return levels & percent differences ───────────────────
outpath = '/scratch/tmiesse/project/inflection_returnlevels_annual3.nc'
ds_rp = xr.open_dataset(outpath, engine='h5netcdf')
ds_rp = ds_out
x, y = ds_rp.x.values, ds_rp.y.values

# Prepare fields for T10, T50, T100
fields_pre = [
    (r'Pre-Inflection $T_{10}$',  ds_rp.rp_pre_10.values),
    (r'Pre-Inflection $T_{50}$',  ds_rp.rp_pre_50.values),
    (r'Pre-Inflection $T_{100}$', ds_rp.rp_pre_100.values),
]
fields_post = [
    (r'Post-Inflection $T_{10}$',  ds_rp.rp_post_10.values),
    (r'Post-Inflection $T_{50}$',  ds_rp.rp_post_50.values),
    (r'Post-Inflection $T_{100}$', ds_rp.rp_post_100.values),
]

# Compute percent differences
fields_diff = []
for (lbl_pre, arr_pre), (lbl_post, arr_post) in zip(fields_pre, fields_post):
    pct = (arr_post - arr_pre) / arr_pre * 100
    Tn = lbl_pre.split('$T_{')[-1].strip('}$')
    fields_diff.append((rf'$\Delta T_{{{Tn}}}$', pct))

all_fields = fields_pre + fields_post + fields_diff
all_fields2 = [fields_pre[1], fields_post[1], fields_diff[1]]
labels     = make_labels(len(all_fields))

# Colormap setup for pre/post
bins_pp = np.linspace(0, 3.5, 8)
cmap_pp = plt.get_cmap('rainbow', len(bins_pp)-1)
norm_pp = mpl.colors.BoundaryNorm(bins_pp, len(bins_pp)-1)

# Colormap for percent diff

ticks_diff = np.arange(-40, 41, 10)
cmap_diff  = plt.get_cmap('coolwarm', len(ticks_diff)-1)
norm_diff  = mpl.colors.BoundaryNorm(ticks_diff, len(ticks_diff)-1)
# Create 3×3 map panel
fig, axes = plt.subplots(
    3, 1, figsize=(4, 12),
    subplot_kw={'projection': ccrs.NorthPolarStereo(central_longitude=-145)},
    gridspec_kw={
        'left':   0.02, 'right':  0.78,
        'top':    0.99, 'bottom': 0.01,
        'wspace': 0.01, 'hspace': -0.4,
    }
)

for idx, ax in enumerate(axes.flat):
    title, data = all_fields2[idx]
    ax.set_extent([-169, -140, 58, 71], crs=ccrs.PlateCarree())
    ax.add_feature(cfeature.LAND,  facecolor='lightgray')
    ax.add_feature(cfeature.OCEAN, facecolor='aliceblue')
    ax.coastlines(resolution='10m', linewidth=0.1)
    ax.gridlines(
        xlocs=np.arange(-180, -100, 5),
        ylocs=np.arange( 50,   90, 3),
        draw_labels=False, linewidth=0.2,
        color='black', alpha=0.3, linestyle='--')

    mask = ~np.isnan(data)
    cmap, norm = (cmap_pp, norm_pp) if idx < 2 else (cmap_diff, norm_diff)
    ax.scatter(
        x[mask], y[mask],
        c=data[mask], cmap=cmap, norm=norm,
        s=5, transform=ccrs.PlateCarree()
    )

    ax.set_title(title, fontsize=11, pad=2)
    ax.text(
        0.02, 1.05, labels[idx],
        transform=ax.transAxes,
        fontsize=10, va='top'
    )

# Shared colorbar for pre/post rows
cax1 = fig.add_axes([0.80, 0.385, 0.02, 0.50])
cb1  = fig.colorbar(
    mpl.cm.ScalarMappable(norm=norm_pp, cmap=cmap_pp),
    cax=cax1, orientation='vertical',
    boundaries=bins_pp, ticks=bins_pp
)
cb1.set_label('WSE [m at MSL]', fontsize=12)

# Shared colorbar for percent‑diff row
cax2 = fig.add_axes([0.80, 0.115, 0.02, 0.235])
cb2  = fig.colorbar(
    mpl.cm.ScalarMappable(norm=norm_diff, cmap=cmap_diff),
    cax=cax2, orientation='vertical',
    ticks=ticks_diff
)
#cb2.set_ticklabels([f"{t:.0f}%" for t in ticks_diff])
cb2.set_label(r'$\Delta T$ [%]', fontsize=12)

plt.savefig(
    '/scratch/tmiesse/project/figures/return_period4presentation.png',
    dpi=720, bbox_inches='tight', pad_inches=0.1)
plt.show()

# %%
ds_rp
# Out:
# <xarray.Dataset> Size: 16MB
# Dimensions:      (node: 182574)
# Coordinates:
#   * node         (node) int64 1MB 0 1 2 3 4 ... 182570 182571 182572 182573
#     x            (node) float64 1MB -158.1 -158.1 -158.1 ... -160.3 -160.2
#     y            (node) float64 1MB 58.94 58.95 58.96 ... 66.41 66.42 66.41
# Data variables:
#     rp_pre_10    (node) float64 1MB nan 0.01945 nan nan ... 0.6299 0.6374 0.6367
#     rp_pre_50    (node) float64 1MB nan 0.02539 nan nan ... 0.857 0.8657 0.865
#     rp_pre_100   (node) float64 1MB nan 0.0279 nan nan ... 0.953 0.9622 0.9616
#     rp_pre_500   (node) float64 1MB nan 0.0337 nan nan ... 1.175 1.185 1.185
#     rp_post_10   (node) float64 1MB 0.02808 0.01869 nan 0.03091 ... nan nan nan
#     rp_post_50   (node) float64 1MB 0.03726 0.02529 nan 0.04047 ... nan nan nan
#     rp_post_100  (node) float64 1MB 0.04114 0.02808 nan 0.04451 ... nan nan nan
#     rp_post_500  (node) float64 1MB 0.05011 0.03453 nan 0.05384 ... nan nan nan

# %%
file = pd.DataFrame({'node': ds_rp.node.values,'x': ds_rp.x.values,'y': ds_rp.y.values,
                     'rp_pre_10': ds_rp.rp_pre_10.values,'rp_pre_50': ds_rp.rp_pre_50.values,
                     'rp_pre_100': ds_rp.rp_pre_100.values,'rp_post_10': ds_rp.rp_post_10.values,
                     'rp_post_50': ds_rp.rp_post_50.values,'rp_post_100': ds_rp.rp_post_100.values})
csv_outpath = '/scratch/tmiesse/project/inflection_returnlevels_annual3.csv'
file.to_csv(csv_outpath)

# %%
file = pd.DataFrame({'node': da_annual.node.values,'x': da_annual.x.values,'y': da_annual.y.values,
                        'annual_max_zeta': da_annual.annual_max_zeta.values,'year': da_annual.year.values})
csv_outpath = '/scratch/tmiesse/project/annual_max.csv'
file.to_csv(csv_outpath)
